# %% [markdown]
# # One Runthrough

# %%
import pandas as pd
from module4.ebc_scoring import EBCScoring


e = EBCScoring()
artifact = e.get_dense_itcc_artifact()

seed, test = e.get_seed_and_test_sets(
    artifact=e.get_dense_itcc_artifact(), sample_size=10
)

df = e.generate_filtered_matrix(test["Drug-Gene"])

scoring = e.generate_ebc_scoring_artifact(
    filtered_matrix=df, seed_pairs=seed["Drug-Gene"]
)

# %%
scoring.head()
# Out:
#                           (dasatinib,stat3)  (norepinephrine,rbp4)  \
# (flavopiridol,nf-kappab)              181.0                  164.0
# (tnf-r2,tnf-r1)                        97.0                  204.0
# (il-2,il-5)                           115.0                  228.0
# (il-11,il-10)                         121.0                  223.0
# (fgf-7,fgf-2)                         170.0                  202.0
#
#                           (aldosterone,nhe-1)  (il-2,stat6)  \
# (flavopiridol,nf-kappab)                167.0         534.0
# (tnf-r2,tnf-r1)                          72.0         139.0
# (il-2,il-5)                              79.0         144.0
# (il-11,il-10)                           103.0         114.0
# (fgf-7,fgf-2)                           156.0         113.0
#
#                           (flecainide,cyp2d6)  (ritonavir,cyp2d6)  \
# (flavopiridol,nf-kappab)                 66.0                38.0
# (tnf-r2,tnf-r1)                          53.0                25.0
# (il-2,il-5)                              45.0                25.0
# (il-11,il-10)                            44.0                23.0
# (fgf-7,fgf-2)                            44.0                15.0
#
#                           (trimethoprim,cyp2c8)  (danazol,shbg)  \
# (flavopiridol,nf-kappab)                   35.0           138.0
# (tnf-r2,tnf-r1)                            21.0            60.0
# (il-2,il-5)                                25.0            70.0
# (il-11,il-10)                              15.0            98.0
# (fgf-7,fgf-2)                              10.0           131.0
#
#                           (enoxacin,cyp1a2)  (taurine,cyp7a1)  SeedSet
# (flavopiridol,nf-kappab)               93.0             147.0    False
# (tnf-r2,tnf-r1)                        74.0             246.0    False
# (il-2,il-5)                           105.0             283.0    False
# (il-11,il-10)                          60.0             235.0    False
# (fgf-7,fgf-2)                          56.0             190.0    False

# %% [markdown]
# The following matrix above gives you the unsorted NxT coocurance matrix.

# %%
from module4.visualize import Visualize

v = Visualize()

# %%
rankings = e.get_rankings(ebc_scoring_artifact=scoring)
rankings
# Out:
# {'(dasatinib,stat3)': {'(dasatinib,stat3)': 1,
#   '(latanoprost,mmp-3)': 2,
#   '(dexamethasone,secretagogin)': 3,
#   '(mitomycin,rad51)': 4,
#   '(mirtazapine,bdnf)': 5,
#   '(infliximab,vegf)': 6,
#   '(bethanechol,gastrin)': 7,
#   '(l-dopa,zif-268)': 8,
#   '(il-2,ap-1)': 9,
#   '(olanzapine,ghrelin)': 10,
#   '(paclitaxel,il-10)': 11,
#   '(creatine,glut4)': 12,
#   '(cisplatin,hmg1)': 13,
#   '(phenytoin,cyp3a4)': 14,
#   '(rosuvastatin,apoe)': 15,
#   '(etoposide,pc-3)': 16,
#   '(fentanyl,mir-190)': 17,
#   '(capsaicin,igf-i)': 18,
#   '(g-csf,cox-2)': 19,
#   '(troglitazone,cyp3a4)': 20,
#   '(saha,waf1)': 21,
#   '(ramipril,aire)': 22,
#   '(docetaxel,dlts)': 23,
#   '(gemcitabine,dlts)': 24,
#   '(atra,cd34)': 25,
#   '(flurbiprofen,cox-2)': 26,
#   '(cisplatin,cd44)': 27,
#   '(carboplatin,vegf)': 28,
#   '(ampicillin,ml-1)': 29,
#   '(diltiazem,ml-1)': 30,
#   '(doxorubicin,cox-2)': 31,
#   '(imiquimod,ifn-alpha)': 32,
#   '(glcnac,rft1)': 33,
#   '(nifedipine,dhps)': 34,
#   '(methacholine,gastrin)': 35,
#   '(pioglitazone,apoe)': 36,
#   '(temozolomide,msh6)': 37,
#   '(cephalexin,mate1)': 38,
#   '(melatonin,lhrh)': 39,
#   '(enoxaparin,tfpi)': 40,
#   '(carbachol,rgs2)': 41,
#   '(carbachol,cgrp)': 42,
#   '(tamoxifen,er-beta)': 43,
#   '(irinotecan,dlts)': 44,
#   '(phenylephrine,endothelin-1)': 45,
#   '(isradipine,midas)': 46,
#   '(propofol,ml-1)': 47,
#   '(capsaicin,beta-endorphin)': 48,
#   '(tamoxifen,med1)': 49,
#   '(dexamethasone,stat3)': 50,
#   '(sn-38,abcg2)': 51,
#   '(pgi2,ml-1)': 52,
#   '(lovastatin,bcl-2)': 53,
#   '(capecitabine,dlts)': 54,
#   '(topotecan,dlts)': 55,
#   '(tamoxifen,her-2)': 56,
#   '(celecoxib,survivin)': 57,
#   '(troglitazone,hmcs)': 58,
#   '(dextromethorphan,cyp2c9)': 59,
#   '(hemin,bach1)': 60,
#   '(cisplatin,hsp25)': 61,
#   '(staurosporine,e-cadherin)': 62,
#   '(vasopressin,adrenocorticotropin)': 63,
#   '(ketamine,bdnf)': 64,
#   '(streptokinase,pai-1)': 65,
#   '(arsenite,cftr)': 66,
#   '(fk506,bdnf)': 67,
#   '(sn-38,beta-glucuronidase)': 68,
#   '(cevimeline,aqp5)': 69,
#   '(suramin,vegf)': 70,
#   '(doxorubicin,xiap)': 71,
#   '(forskolin,egr-1)': 72,
#   '(midazolam,ml-1)': 73,
#   '(pantoprazole,gastrin)': 74,
#   '(il-1ra,icam-1)': 75,
#   '(infliximab,icer)': 76,
#   '(varenicline,icer)': 77,
#   '(beta-estradiol,gnrh)': 78,
#   '(oxycodone,herg)': 79,
#   '(ornithine,samdc)': 80,
#   '(norepinephrine,cgrp)': 81,
#   '(pyridoxal,gad65)': 82,
#   '(palivizumab,icer)': 83,
#   '(leflunomide,bcrp)': 84,
#   '(doxycycline,gdnf)': 85,
#   '(inulin,cpah)': 86,
#   '(adalimumab,icer)': 87,
#   '(theophylline,ml-1)': 88,
#   '(ornithine,adometdc)': 89,
#   '(propranolol,ml-1)': 90,
#   '(fluorescein,cd14)': 91,
#   '(erythromycin,ml-1)': 92,
#   '(glimepiride,caveolin-1)': 93,
#   '(fluorescein,cd45)': 94,
#   '(camptothecin,tdp1)': 95,
#   '(sumatriptan,cgrp)': 96,
#   '(vasopressin,calcitonin)': 97,
#   '(cisplatin,c-abl)': 98,
#   '(fluorescein,lectin)': 99,
#   '(fluorescein,cd42b)': 100,
#   '(thyroglobulin,calcitonin)': 101,
#   '(gonadorelin,gnrh)': 102,
#   '(dexamethasone,pref-1)': 103,
#   '(atra,gnt-v)': 104,
#   '(atra,gm-csf)': 105,
#   '(capsaicin,glp-1)': 106,
#   '(atra,rar-alpha)': 107,
#   '(tamoxifen,nppb)': 108,
#   '(oxytocin,ghrelin)': 109,
#   '(cisplatin,chk1)': 110,
#   '(imipenem,ml-1)': 111,
#   '(atra,stat3)': 112,
#   '(atra,ifn-gamma)': 113,
#   '(estradiol,egfr)': 114,
#   '(propofol,pkc-alpha)': 115,
#   '(aldosterone,nedd4-2)': 116,
#   '(genistein,brca1)': 117,
#   '(cisplatin,nat1)': 118,
#   '(hyaluronan,versican)': 119,
#   '(forskolin,gastrin)': 120,
#   '(etoposide,brca1)': 121,
#   '(doxorubicin,foxo3a)': 122,
#   '(forskolin,ifn-gamma)': 123,
#   '(indomethacin,vegf)': 124,
#   '(pirenzepine,gastrin)': 125,
#   '(pravastatin,adiponectin)': 126,
#   '(captopril,kallikrein)': 127,
#   '(arsenite,hif-1)': 128,
#   '(dexamethasone,sp-c)': 129,
#   '(epirubicin,filgrastim)': 130,
#   '(prazosin,vasa)': 131,
#   '(vinorelbine,filgrastim)': 132,
#   '(neratinib,abcb1)': 133,
#   '(norepinephrine,vasa)': 134,
#   '(doxorubicin,bcl-xl)': 135,
#   '(meloxicam,cyclooxygenase-1)': 136,
#   '(clomipramine,herg)': 137,
#   '(capsaicin,cox-2)': 138,
#   '(glimepiride,enos)': 139,
#   '(melatonin,12-lox)': 140,
#   '(aldosterone,romk)': 141,
#   '(cisplatin,vegf)': 142,
#   '(genistein,cyclooxygenase-2)': 143,
#   '(rapamycin,skp2)': 144,
#   '(il-2,cxcr3)': 145,
#   '(chlorambucil,mrp1)': 146,
#   '(melatonin,ins-1)': 147,
#   '(promethazine,herg)': 148,
#   '(doxorubicin,pc-3)': 149,
#   '(metyrapone,adrenocorticotropin)': 150,
#   '(thymalfasin,tace)': 151,
#   '(daunorubicin,p-gp)': 152,
#   '(estradiol,bfgf)': 153,
#   '(dexamethasone,irs-1)': 154,
#   '(methylphenidate,darpp-32)': 155,
#   '(atra,mef2c)': 156,
#   '(hyaluronan,erbb2)': 157,
#   '(dexamethasone,ikappabalpha)': 158,
#   '(oxaliplatin,yb-1)': 159,
#   '(calcitriol,cyp27b1)': 160,
#   '(collagenase,ap-1)': 161,
#   '(chloramphenicol,mdr1)': 162,
#   '(chloramphenicol,pai-1)': 163,
#   '(cisplatin,yb-1)': 164,
#   '(chloramphenicol,beta-actin)': 165,
#   '(chloramphenicol,pomc)': 166,
#   '(quetiapine,abcb1)': 167,
#   '(pertuzumab,her3)': 168,
#   '(rapamycin,pmr1)': 169,
#   '(simvastatin,slco1b1)': 170,
#   '(cetuximab,larc)': 171,
#   '(halothane,ml-1)': 172,
#   '(dexamethasone,l-pgds)': 173,
#   '(il-2,p-selectin)': 174,
#   '(staurosporine,pkc-zeta)': 175,
#   '(phenytoin,ml-1)': 176,
#   '(5-asa,sasp)': 177,
#   '(docetaxel,nf-kappab)': 178,
#   '(etoposide,cyr61)': 179,
#   '(ndga,indo)': 180,
#   '(forskolin,nnos)': 181,
#   '(curcumin,hsp70)': 182,
#   '(pioglitazone,vegf)': 183,
#   '(metformin,glut1)': 184,
#   '(glcnac,mgat3)': 185,
#   '(warfarin,apoe)': 186,
#   '(salbutamol,copd)': 187,
#   '(doxycycline,sp-b)': 188,
#   '(il-2,cdk4)': 189,
#   '(cyclosporin,col6a1)': 190,
#   '(etoposide,parp)': 191,
#   '(rapamycin,tsc1)': 192,
#   '(ouabain,adenosinetriphosphatase)': 193,
#   '(imatinib,pc-3)': 194,
#   '(ouabain,phospholipase)': 195,
#   '(rosiglitazone,inos)': 196,
#   '(nebivolol,enos)': 197,
#   '(paclitaxel,pc-3)': 198,
#   '(doxycycline,smad7)': 199,
#   '(modafinil,orexin)': 200,
#   '(cefadroxil,pept2)': 201,
#   '(rolipram,creb)': 202,
#   '(pioglitazone,enos)': 203,
#   '(cisplatin,nox3)': 204,
#   '(atra,rar-beta)': 205,
#   '(cisplatin,hsp90)': 206,
#   '(phenylephrine,sirt1)': 207,
#   '(imatinib,cd34)': 208,
#   '(genistein,mmp-9)': 209,
#   '(aldosterone,per1)': 210,
#   '(rapamycin,cdc25b)': 211,
#   '(prednisolone,rhoa)': 212,
#   '(ritonavir,cd36)': 213,
#   '(noradrenaline,calcitonin)': 214,
#   '(gm-csf,bcl-2)': 215,
#   '(troglitazone,cyp3a)': 216,
#   '(menadione,nadph)': 217,
#   '(staurosporine,hsp27)': 218,
#   '(apap,mrp3)': 219,
#   '(n-acetylcysteine,nadph)': 220,
#   '(verapamil,calcitonin)': 221,
#   '(vardenafil,abcb1)': 222,
#   '(aldosterone,wnk4)': 223,
#   '(troglitazone,cyp1a1)': 224,
#   '(g-csf,socs3)': 225,
#   '(atra,cox-1)': 226,
#   '(chloramphenicol,ifn-beta)': 227,
#   '(vinorelbine,bcl-2)': 228,
#   '(tamoxifen,maspin)': 229,
#   '(ru486,aromatase)': 230,
#   '(daunorubicin,igf-i)': 231,
#   '(dexamethasone,sp-d)': 232,
#   '(alteplase,reteplase)': 233,
#   '(doxorubicin,survivin)': 234,
#   '(aldosterone,nhe-1)': 235,
#   '(lovastatin,survivin)': 236,
#   '(estradiol,cd40l)': 237,
#   '(domperidone,nicotinamide)': 238,
#   '(cyclosporine,rapa)': 239,
#   '(tacrolimus,il-10)': 240,
#   '(pioglitazone,apoa-i)': 241,
#   '(irinotecan,ces2)': 242,
#   '(paclitaxel,nfkappab)': 243,
#   '(genistein,osteoprotegerin)': 244,
#   '(hydroquinone,dt-diaphorase)': 245,
#   '(cisplatin,mad2)': 246,
#   '(cyclosporin,il-5)': 247,
#   '(atra,apr3)': 248,
#   '(dexamethasone,sr-bi)': 249,
#   '(indomethacin,il-18)': 250,
#   '(oxytocin,sf-1)': 251,
#   '(clenbuterol,igf-i)': 252,
#   '(nifedipine,nadph)': 253,
#   '(il-2,crem)': 254,
#   '(prednisolone,il-18)': 255,
#   '(paclitaxel,s100p)': 256,
#   '(bleomycin,parp)': 257,
#   '(mineralocorticoids,sgk1)': 258,
#   '(misoprostol,cox-2)': 259,
#   '(betaine,igf-i)': 260,
#   '(geldanamycin,hsp70)': 261,
#   '(cyclophosphamide,ifn-gamma)': 262,
#   '(imipramine,bdnf)': 263,
#   '(ara-c,p-gp)': 264,
#   '(rolipram,il-10)': 265,
#   '(cisplatin,cited2)': 266,
#   '(pge2,inositol)': 267,
#   '(noradrenaline,inositol)': 268,
#   '(metformin,lkb1)': 269,
#   '(norepinephrine,inositol)': 270,
#   '(furosemide,kallikrein)': 271,
#   '(etoposide,xiap)': 272,
#   '(methylprednisolone,il-10)': 273,
#   '(pioglitazone,niddm)': 274,
#   '(oxytocin,rgs2)': 275,
#   '(lidocaine,acyltransferase)': 276,
#   '(cisplatin,caspase-2)': 277,
#   '(forskolin,gnrh)': 278,
#   '(rapamycin,eef2)': 279,
#   '(g-csf,stat1)': 280,
#   '(estradiol,hsd17b7)': 281,
#   '(g-csf,jak1)': 282,
#   '(imatinib,ifn-alpha)': 283,
#   '(rapamycin,rps6)': 284,
#   '(estradiol,gnrh-r)': 285,
#   '(fk506,ikappabalpha)': 286,
#   '(g-csf,jak2)': 287,
#   '(aldosterone,phospholipase)': 288,
#   '(doxorubicin,p300)': 289,
#   '(doxorubicin,il-1)': 290,
#   '(vincristine,hsp27)': 291,
#   '(norepinephrine,phospholipase)': 292,
#   '(estradiol,cftr)': 293,
#   '(mivacurium,pseudocholinesterase)': 294,
#   '(flutamide,aadac)': 295,
#   '(tacrolimus,ifn-gamma)': 296,
#   '(atorvastatin,e-selectin)': 297,
#   '(lamotrigine,glur1)': 298,
#   '(minocycline,glur1)': 299,
#   '(cysteamine,gastrin)': 300,
#   '(il-2,cx3cr1)': 301,
#   '(mivacurium,butyrylcholinesterase)': 302,
#   '(dexamethasone,cd163)': 303,
#   '(atra,irf-1)': 304,
#   '(atra,nf-kappab)': 305,
#   '(naloxone,cgrp)': 306,
#   '(hemin,nrf2)': 307,
#   '(pge2,socs3)': 308,
#   '(isoproterenol,il-1)': 309,
#   '(sorafenib,mcl-1)': 310,
#   '(atorvastatin,mmp-9)': 311,
#   '(halofantrine,herg)': 312,
#   '(pge2,gastrin)': 313,
#   '(octreotide,gastrin)': 314,
#   '(dexamethasone,adiponectin)': 315,
#   '(candesartan,vegf)': 316,
#   '(flurbiprofen,cgrp)': 317,
#   '(chlorpromazine,herg)': 318,
#   '(acarbose,niddm)': 319,
#   '(acarbose,iddm)': 320,
#   '(ranitidine,gastrin)': 321,
#   '(rosuvastatin,enos)': 322,
#   '(fluoxetine,herg)': 323,
#   '(diuretics,copd)': 324,
#   '(metoprolol,copd)': 325,
#   '(moxifloxacin,herg)': 326,
#   '(prostacyclin,calcitonin)': 327,
#   '(ajmaline,herg)': 328,
#   '(sn-38,udp-glucuronosyltransferase)': 329,
#   '(haloperidol,herg)': 330,
#   '(curcumin,bdnf)': 331,
#   '(glucosamine,furin)': 332,
#   '(budesonide,copd)': 333,
#   '(tamoxifen,hoxb13)': 334,
#   '(corticosteroids,inos)': 335,
#   '(hesperetin,herg)': 336,
#   '(alendronate,rankl)': 337,
#   '(estradiol,cyp1a1)': 338,
#   '(fenofibrate,enos)': 339,
#   '(carvedilol,herg)': 340,
#   '(cilomilast,copd)': 341,
#   '(cabergoline,igf-i)': 342,
#   '(indacaterol,copd)': 343,
#   '(dexamethasone,cyp1a1)': 344,
#   '(docetaxel,cox-2)': 345,
#   '(haloperidol,pomc)': 346,
#   '(fluvastatin,inos)': 347,
#   '(troglitazone,e-cadherin)': 348,
#   '(fenofibrate,tlr4)': 349,
#   '(theophylline,cyp3a)': 350,
#   '(donepezil,igf-i)': 351,
#   '(lmwh,tfpi)': 352,
#   '(fluvastatin,enos)': 353,
#   '(phenytoin,cyp3a)': 354,
#   '(cisplatin,mkk3)': 355,
#   '(cyclosporine,statin)': 356,
#   '(celecoxib,caspase-3)': 357,
#   '(aldosterone,sf-1)': 358,
#   '(dexamethasone,kallikrein)': 359,
#   '(celecoxib,bcl-2)': 360,
#   '(aldosterone,a-ii)': 361,
#   '(capsaicin,pi3k)': 362,
#   '(g-csf,cd11b)': 363,
#   '(simvastatin,oatp1b1)': 364,
#   '(imatinib,adiponectin)': 365,
#   '(cisplatin,tnfr1)': 366,
#   '(genistein,glut1)': 367,
#   '(indomethacin,ppargamma)': 368,
#   '(cyclosporin,cox-2)': 369,
#   '(venlafaxine,sert)': 370,
#   '(etoposide,reticulum)': 371,
#   '(forskolin,fmlp)': 372,
#   '(taurine,kallikrein)': 373,
#   '(estradiol,beta-endorphin)': 374,
#   '(forskolin,pacap)': 375,
#   '(dapsone,pgd2)': 376,
#   '(estradiol,rankl)': 377,
#   '(bortezomib,pp2a)': 378,
#   '(pge2,il-1ra)': 379,
#   '(medetomidine,gastrin)': 380,
#   '(sorafenib,tace)': 381,
#   '(atorvastatin,cox-2)': 382,
#   '(sulfasalazine,nat2)': 383,
#   '(gemcitabine,vegf)': 384,
#   '(il-2,il-27)': 385,
#   '(protamine,testis-specific)': 386,
#   '(propranolol,vegf)': 387,
#   '(cyclophosphamide,etanercept)': 388,
#   '(apomorphine,gastrin)': 389,
#   '(irinotecan,drg1)': 390,
#   '(azathioprine,etanercept)': 391,
#   '(miconazole,herg)': 392,
#   '(il-2,stat1)': 393,
#   '(oxytocin,pla2)': 394,
#   '(pge2,mmp-3)': 395,
#   '(minocycline,fmr1)': 396,
#   '(norepinephrine,cort)': 397,
#   '(estriol,lactogen)': 398,
#   '(rizatriptan,cgrp)': 399,
#   '(alendronate,hips)': 400,
#   '(phosphatidylserine,phospholipase)': 401,
#   '(sevoflurane,hsp70)': 402,
#   '(theophylline,il-10)': 403,
#   '(lubiprostone,cftr)': 404,
#   '(rapamycin,rheb)': 405,
#   '(estradiol,cort)': 406,
#   '(mirtazapine,comt)': 407,
#   '(estrone,hsd17b1)': 408,
#   '(meth,nnos)': 409,
#   '(il-2,hdac1)': 410,
#   '(arsenite,arsa)': 411,
#   '(primaquine,g6pd)': 412,
#   '(aldosterone,enacalpha)': 413,
#   '(imipramine,cyp2c19)': 414,
#   '(gemcitabine,hsp27)': 415,
#   '(noradrenaline,vasa)': 416,
#   '(trastuzumab,rac1)': 417,
#   '(perindopril,vegf)': 418,
#   '(cyclosporine,hnf4alpha)': 419,
#   '(cisplatin,cmoat)': 420,
#   '(arsenite,ang-1)': 421,
#   '(risperidone,cyp3a)': 422,
#   '(dexamethasone,resistin)': 423,
#   '(forskolin,nachr)': 424,
#   '(cisplatin,napa)': 425,
#   '(trastuzumab,egfr)': 426,
#   '(risperidone,cyp3a4)': 427,
#   '(vincristine,bcl-2)': 428,
#   '(pge2,il-13)': 429,
#   '(warfarin,hips)': 430,
#   '(pge2,igfbp-5)': 431,
#   '(fluoxetine,s100b)': 432,
#   '(paclitaxel,dppiv)': 433,
#   '(rapamycin,ccr5)': 434,
#   '(tacrolimus,vegf)': 435,
#   '(celecoxib,e-cadherin)': 436,
#   '(hyaluronan,tsg-6)': 437,
#   '(creatine,igf-i)': 438,
#   '(capsaicin,calcitonin)': 439,
#   '(gp120,lectin)': 440,
#   '(forskolin,il-1)': 441,
#   '(tranylcypromine,bdnf)': 442,
#   '(melatonin,ml-1)': 443,
#   '(hyaluronan,ec-sod)': 444,
#   '(oxaliplatin,kras)': 445,
#   '(telmisartan,enos)': 446,
#   '(lovastatin,p27kip1)': 447,
#   '(dexamethasone,p450scc)': 448,
#   '(triiodothyronine,shbg)': 449,
#   '(phosphatidylserine,lactadherin)': 450,
#   '(oxaliplatin,egfr)': 451,
#   '(phosphatidylserine,gas6)': 452,
#   '(estradiol,tebg)': 453,
#   '(irinotecan,egfr)': 454,
#   '(pyridostigmine,ghrh)': 455,
#   '(dexamethasone,pthrp)': 456,
#   '(isoproterenol,beta-glucuronidase)': 457,
#   '(simvastatin,niddm)': 458,
#   '(glibenclamide,niddm)': 459,
#   '(trastuzumab,p27kip1)': 460,
#   '(rituximab,etanercept)': 461,
#   '(haloperidol,alpha-msh)': 462,
#   '(azithromycin,copd)': 463,
#   '(resveratrol,enos)': 464,
#   '(carbachol,mucin)': 465,
#   '(sulindac,ppargamma)': 466,
#   '(ketamine,ml-1)': 467,
#   '(hemin,inos)': 468,
#   '(collagenase,stromelysin-2)': 469,
#   '(isoprenaline,cgrp)': 470,
#   '(il-2,ldlr)': 471,
#   '(aprotinin,il-10)': 472,
#   '(curcumin,caspase-8)': 473,
#   '(pge2,tgf-alpha)': 474,
#   '(clenbuterol,ml-1)': 475,
#   '(budesonide,eotaxin)': 476,
#   '(calcitriol,pthrp)': 477,
#   '(dexamethasone,gilz)': 478,
#   '(roflumilast,copd)': 479,
#   '(simvastatin,p-selectin)': 480,
#   '(quinidine,herg)': 481,
#   '(aldosterone,ctrp1)': 482,
#   '(pimozide,gnrh)': 483,
#   '(metformin,oct3)': 484,
#   '(paclitaxel,caspase-3)': 485,
#   '(forskolin,ghrh)': 486,
#   '(troglitazone,niddm)': 487,
#   '(estrone,hoat3)': 488,
#   '(dexamethasone,dheas)': 489,
#   '(il-2,ml-1)': 490,
#   '(corticosteroids,pprom)': 491,
#   '(atra,p-gp)': 492,
#   '(rapamycin,foxp3)': 493,
#   '(estrone,mrp1)': 494,
#   '(vasopressin,inositol)': 495,
#   '(fibrates,apoc-iii)': 496,
#   '(rosiglitazone,mcp-1)': 497,
#   '(n-acetyl-d-glucosamine,lectin)': 498,
#   '(collagenase,timp-2)': 499,
#   '(hyaluronan,aggrecan)': 500,
#   '(calcitriol,il-10)': 501,
#   '(rosiglitazone,apoa5)': 502,
#   '(lidoflazine,herg)': 503,
#   '(captopril,iddm)': 504,
#   '(il-2,il-22)': 505,
#   '(pravastatin,enos)': 506,
#   '(telithromycin,mrp2)': 507,
#   '(chlorpropamide,niddm)': 508,
#   '(resveratrol,caspase-3)': 509,
#   '(metformin,glp-1)': 510,
#   '(dexamethasone,5-lipoxygenase)': 511,
#   '(carnitine,pparalpha)': 512,
#   '(prednisone,il-10)': 513,
#   '(fenofibrate,apoa-i)': 514,
#   '(aldosterone,p-gp)': 515,
#   '(minocycline,hmgb1)': 516,
#   '(primaquine,herg)': 517,
#   '(nitroprusside,inos)': 518,
#   '(riluzole,hsf1)': 519,
#   '(cisplatin,octn2)': 520,
#   '(rapamycin,phas-i)': 521,
#   '(raloxifene,menin)': 522,
#   '(oxaliplatin,chk2)': 523,
#   '(itraconazole,mtor)': 524,
#   '(methacholine,atopy)': 525,
#   '(sildenafil,copd)': 526,
#   '(carnitine,cact)': 527,
#   '(isoproterenol,calcitonin)': 528,
#   '(indomethacin,calcitonin)': 529,
#   '(cisplatin,hipk2)': 530,
#   '(nateglinide,glp-1)': 531,
#   '(paclitaxel,pi3k)': 532,
#   '(theophylline,gm-csf)': 533,
#   '(ru486,lhrh)': 534,
#   '(celecoxib,ho-1)': 535,
#   '(fentanyl,cyp3a)': 536,
#   '(ampicillin,acylase)': 537,
#   '(carbachol,trpc6)': 538,
#   '(danazol,shbg)': 539,
#   '(atra,g-csf)': 540,
#   '(dexamethasone,beta-induced)': 541,
#   '(fk506,ifn-gamma)': 542,
#   '(fk506,il-13)': 543,
#   '(methimazole,fmo1)': 544,
#   '(phenylephrine,pdha)': 545,
#   '(cisplatin,bcl-xl)': 546,
#   '(l-citrulline,nnos)': 547,
#   '(sulphasalazine,sasp)': 548,
#   '(indomethacin,15-pgdh)': 549,
#   '(hydrocortisone,icam-1)': 550,
#   '(gm-csf,il-1ra)': 551,
#   '(estrone,bcrp)': 552,
#   '(fenoterol,copd)': 553,
#   '(methylprednisolone,g-csf)': 554,
#   '(captopril,copd)': 555,
#   '(corticosteroids,g-csf)': 556,
#   '(verteporfin,vegf)': 557,
#   '(propofol,bcl-2)': 558,
#   '(gliclazide,niddm)': 559,
#   '(genistein,icam-1)': 560,
#   '(cisplatin,cdk2)': 561,
#   '(estradiol,l-pgds)': 562,
#   '(amlodipine,egfr)': 563,
#   '(naloxone,copd)': 564,
#   '(curcumin,mmp-3)': 565,
#   '(prednisone,p-gp)': 566,
#   '(riluzole,bcrp)': 567,
#   '(vasopressin,calmodulin)': 568,
#   '(aldosterone,inos)': 569,
#   '(il-2,aicar)': 570,
#   '(doxorubicin,hsp27)': 571,
#   '(estradiol,adiponectin)': 572,
#   '(gentamicin,caspase-3)': 573,
#   '(simvastatin,mucin)': 574,
#   '(ziprasidone,cyp3a4)': 575,
#   '(fk506,il-5)': 576,
#   '(haloperidol,drd2)': 577,
#   '(dhea,ppar)': 578,
#   '(paroxetine,bdnf)': 579,
#   '(aldosterone,leu-enkephalin)': 580,
#   '(clozapine,tspo)': 581,
#   '(dexamethasone,rasd1)': 582,
#   '(colchicine,mefv)': 583,
#   '(dtic,cyp1a1)': 584,
#   '(rosiglitazone,adipor2)': 585,
#   '(rapamycin,her2)': 586,
#   '(phenylephrine,inositol)': 587,
#   '(gm-csf,survivin)': 588,
#   '(cyclosporine,vegf)': 589,
#   '(losartan,cx43)': 590,
#   '(flutamide,cyp1a2)': 591,
#   '(noradrenaline,cgrp)': 592,
#   '(carnitine,cpt1b)': 593,
#   '(atra,ml-1)': 594,
#   '(forskolin,igf-i)': 595,
#   '(pioglitazone,visfatin)': 596,
#   '(fibrates,mdr2)': 597,
#   '(rapamycin,egfr)': 598,
#   '(6-mercaptopurine,nurr1)': 599,
#   '(creatine,transamidinase)': 600,
#   '(dobutamine,mcp-1)': 601,
#   '(minocycline,inos)': 602,
#   '(hydroxyurea,il-13)': 603,
#   '(estradiol,il-1)': 604,
#   '(omeprazole,cyp3a)': 605,
#   '(propofol,beta2)': 606,
#   '(leflunomide,inos)': 607,
#   '(estradiol,igfbp-2)': 608,
#   '(estradiol,lactogen)': 609,
#   '(benzbromarone,adiponectin)': 610,
#   '(glucosamine,mucin)': 611,
#   '(flurbiprofen,15-pgdh)': 612,
#   '(bleomycin,gm-csf)': 613,
#   '(naloxone,alpha-msh)': 614,
#   '(fk506,igf-i)': 615,
#   '(estrone,dheas)': 616,
#   '(diazepam,cyp3a4)': 617,
#   '(estrone,shbg)': 618,
#   '(arsenite,hsp27)': 619,
#   '(cyclophosphamide,cyp2b6)': 620,
#   '(aldosterone,dheas)': 621,
#   '(pge2,lhrh)': 622,
#   '(dexamethasone,gamma-glutamyltransferase)': 623,
#   '(fenofibrate,paraoxonase)': 624,
#   '(trastuzumab,vegf)': 625,
#   '(decitabine,p53r2)': 626,
#   '(cilostazol,ampk)': 627,
#   '(genistein,mcp-1)': 628,
#   '(genistein,fgf-2)': 629,
#   '(corticosteroids,adrenocorticotropin)': 630,
#   '(reteplase,alteplase)': 631,
#   '(dexamethasone,nhe3)': 632,
#   '(doxorubicin,vegf)': 633,
#   '(estradiol,bmp-7)': 634,
#   '(bortezomib,skp2)': 635,
#   '(melatonin,vegf)': 636,
#   '(gemcitabine,hcnt1)': 637,
#   '(hyaluronan,adiponectin)': 638,
#   '(il-2,il-17)': 639,
#   '(rabeprazole,mucin)': 640,
#   '(sertindole,5-ht2c)': 641,
#   '(troglitazone,nf-kappab)': 642,
#   '(secretin,calcitonin)': 643,
#   '(aldosterone,adrenocorticotropin)': 644,
#   '(nadh,nox-1)': 645,
#   '(nadh,enox2)': 646,
#   '(imipramine,ugt1a4)': 647,
#   '(hyaluronan,mmp-13)': 648,
#   '(oxytocin,beta-endorphin)': 649,
#   '(aldosterone,cyp11b1)': 650,
#   '(atorvastatin,oatp1b1)': 651,
#   '(losartan,mmp-2)': 652,
#   '(rapamycin,ogg1)': 653,
#   '(clonidine,pnmt)': 654,
#   '(atra,cyp26a1)': 655,
#   '(methotrexate,hoat3)': 656,
#   '(atra,vegf)': 657,
#   '(bortezomib,amyloidosis)': 658,
#   '(propranolol,gastrin)': 659,
#   '(hyaluronan,hyal2)': 660,
#   '(l-citrulline,inos)': 661,
#   '(pge2,rankl)': 662,
#   '(atra,pi3k)': 663,
#   '(pgi2,ptgis)': 664,
#   '(vasopressin,nnos)': 665,
#   '(phosphatidylserine,pssa)': 666,
#   '(rapamycin,igf-i)': 667,
#   '(melatonin,caspase-3)': 668,
#   '(ivacaftor,cftr)': 669,
#   '(il-2,phospholipase)': 670,
#   '(dexamethasone,edn1)': 671,
#   '(rapamycin,mdm2)': 672,
#   '(curcumin,blys)': 673,
#   '(lactulose,beta-galactosidase)': 674,
#   '(colchicine,gm-csf)': 675,
#   '(aldosterone,alpha-msh)': 676,
#   '(dexamethasone,il-1ra)': 677,
#   '(atorvastatin,cd40l)': 678,
#   '(zidovudine,ifn-alpha)': 679,
#   '(rifampin,mrp2)': 680,
#   '(cyclophosphamide,ifn-alpha)': 681,
#   '(il-2,il-16)': 682,
#   '(dexamethasone,muc1)': 683,
#   '(sn-38,bcrp)': 684,
#   '(corticosteroids,fsgs)': 685,
#   '(pioglitazone,ampk)': 686,
#   '(bortezomib,caspase-3)': 687,
#   '(melphalan,ifn-gamma)': 688,
#   '(pge2,ml-1)': 689,
#   '(rapamycin,reticulum)': 690,
#   '(estradiol,p-gp)': 691,
#   '(rosiglitazone,il-1ra)': 692,
#   '(etoposide,filgrastim)': 693,
#   '(daunorubicin,mrp1)': 694,
#   '(genistein,sp-a)': 695,
#   '(losartan,jak2)': 696,
#   '(atorvastatin,mcp-1)': 697,
#   '(curcumin,mtor)': 698,
#   '(pge2,15-pgdh)': 699,
#   '(atra,cd38)': 700,
#   '(anticholinergics,copd)': 701,
#   '(il-2,jak3)': 702,
#   '(g-csf,bfgf)': 703,
#   '(nadh,ndh2)': 704,
#   '(pioglitazone,lox-1)': 705,
#   '(carboplatin,g-csf)': 706,
#   '(propofol,beta-endorphin)': 707,
#   '(selegiline,cyp2b6)': 708,
#   '(hyaluronidase,mucin)': 709,
#   '(icatibant,kallikrein)': 710,
#   '(clomiphene,gnrh)': 711,
#   '(il-2,pthrp)': 712,
#   '(estradiol,cyp1b1)': 713,
#   '(propranolol,fmlp)': 714,
#   '(dexamethasone,myocilin)': 715,
#   '(etanercept,amyloidosis)': 716,
#   '(theophylline,cyp2e1)': 717,
#   '(bupropion,cyp2b6)': 718,
#   '(paclitaxel,cox-2)': 719,
#   '(pge2,mpges)': 720,
#   '(estradiol,sf-1)': 721,
#   '(dexamethasone,pnmt)': 722,
#   '(orlistat,cyp3a4)': 723,
#   '(tamoxifen,mcp-1)': 724,
#   '(sulindac,nag-1)': 725,
#   '(forskolin,proenkephalin)': 726,
#   '(fentanyl,ml-1)': 727,
#   '(estradiol,cgrp)': 728,
#   '(menadione,sod1)': 729,
#   '(prostacyclin,cox-1)': 730,
#   '(atra,irs-1)': 731,
#   '(mibefradil,cyp3a4)': 732,
#   '(carvedilol,p-gp)': 733,
#   '(raloxifene,ki-67)': 734,
#   '(curcumin,beta-catenin)': 735,
#   '(rapamycin,irs-1)': 736,
#   '(cimetidine,ifn-alpha)': 737,
#   '(rosiglitazone,nefa)': 738,
#   '(hyaluronate,mesoderm)': 739,
#   '(duloxetine,bdnf)': 740,
#   '(trabectedin,p-gp)': 741,
#   '(bacitracin,lhrh)': 742,
#   '(analgesics,p-gp)': 743,
#   '(gm-csf,cd34)': 744,
#   '(plerixafor,cd34)': 745,
#   '(losartan,ctgf)': 746,
#   '(ddavp,p-selectin)': 747,
#   '(pge2,ccr7)': 748,
#   '(venlafaxine,bdnf)': 749,
#   '(vincristine,traf1)': 750,
#   '(indinavir,cyp3a4)': 751,
#   '(aminopterin,hoat1)': 752,
#   '(metformin,resistin)': 753,
#   '(gm-csf,mmp-12)': 754,
#   '(dhea,ppargamma)': 755,
#   '(cisplatin,habp1)': 756,
#   '(estradiol,brca1)': 757,
#   '(paclitaxel,bcl-xl)': 758,
#   '(rapamycin,rictor)': 759,
#   '(nadh,reticulum)': 760,
#   '(adomet,mat1a)': 761,
#   '(diclofenac,ho-1)': 762,
#   '(dexamethasone,cyp2e1)': 763,
#   '(dexamethasone,aqp1)': 764,
#   '(flavopiridol,mcl-1)': 765,
#   '(formoterol,gm-csf)': 766,
#   '(tranilast,bfgf)': 767,
#   '(captopril,kininogen)': 768,
#   '(dutasteride,pca3)': 769,
#   '(lenalidomide,amyloidosis)': 770,
#   '(estradiol,apoe)': 771,
#   '(infliximab,gm-csf)': 772,
#   '(loratadine,cyp3a4)': 773,
#   '(resveratrol,erbb2)': 774,
#   '(meperidine,il-1)': 775,
#   '(melatonin,beta-endorphin)': 776,
#   '(memantine,bdnf)': 777,
#   '(metyrapone,cyp1a1)': 778,
#   '(triiodothyronine,apob)': 779,
#   '(hydrocortisone,endothelin-1)': 780,
#   '(estradiol,mcp-1)': 781,
#   '(doxycycline,mmp-3)': 782,
#   '(mifepristone,gnrh)': 783,
#   '(isoproterenol,cgrp)': 784,
#   '(loratadine,cyp2d6)': 785,
#   '(corticosteroids,cox-2)': 786,
#   '(metformin,pten)': 787,
#   '(capecitabine,larc)': 788,
#   '(beta-estradiol,lhrh)': 789,
#   '(lovastatin,rhoa)': 790,
#   '(n-acetylcysteine,egfr)': 791,
#   '(aldosterone,k-ras)': 792,
#   '(mineralocorticoids,kallikrein)': 793,
#   '(rapamycin,trpm6)': 794,
#   '(isoproterenol,mucin)': 795,
#   '(dexamethasone,p-gp)': 796,
#   '(gm-csf,cd86)': 797,
#   '(auranofin,il-1)': 798,
#   '(infliximab,cvid)': 799,
#   '(rapamycin,hgps)': 800,
#   '(desmopressin,aqp2)': 801,
#   '(dexfenfluramine,niddm)': 802,
#   '(everolimus,nets)': 803,
#   '(temsirolimus,vegf)': 804,
#   '(l-dopa,fosb)': 805,
#   '(gentamicin,megalin)': 806,
#   '(ctla4ig,apcs)': 807,
#   '(fluoroquinolones,copd)': 808,
#   '(paclitaxel,stat3)': 809,
#   '(aldosterone,p450aldo)': 810,
#   '(cisplatin,caspase-8)': 811,
#   '(gp120,nf-kappab)': 812,
#   '(gm-csf,cd14)': 813,
#   '(apap,cyp3a4)': 814,
#   '(fk506,hsp56)': 815,
#   '(etoposide,mrp3)': 816,
#   '(ropinirole,zif-268)': 817,
#   '(cisplatin,abcc2)': 818,
#   '(norepinephrine,kallikrein)': 819,
#   '(zidovudine,il-1)': 820,
#   '(citrulline,inos)': 821,
#   '(losartan,nf-kappab)': 822,
#   '(lidocaine,cyp3a4)': 823,
#   '(desipramine,herg)': 824,
#   '(thyroxine,shbg)': 825,
#   '(naringenin,apob)': 826,
#   '(pgi2,pgis)': 827,
#   '(vasopressin,lhrh)': 828,
#   '(streptozocin,niddm)': 829,
#   '(dhea,factor-1)': 830,
#   '(vasopressin,beta-endorphin)': 831,
#   '(melatonin,igf-i)': 832,
#   '(ornithine,ornt1)': 833,
#   '(daunorubicin,nfkappab)': 834,
#   '(indomethacin,il-11)': 835,
#   '(noradrenaline,lhrh)': 836,
#   '(betaine,bgt1)': 837,
#   '(dexamethasone,p300)': 838,
#   '(resveratrol,gli1)': 839,
#   '(amiodarone,herg)': 840,
#   '(corticosteroids,p-gp)': 841,
#   '(atra,tsp-1)': 842,
#   '(atra,trkb)': 843,
#   '(doxorubicin,caspase-3)': 844,
#   '(creatine,gamt)': 845,
#   '(vorinostat,ctcl)': 846,
#   '(dexamethasone,c-fms)': 847,
#   '(escitalopram,bdnf)': 848,
#   '(topiramate,cgrp)': 849,
#   '(norepinephrine,sert)': 850,
#   '(pyridoxal,palp)': 851,
#   '(5-asa,cox-2)': 852,
#   '(norepinephrine,maoa)': 853,
#   '(melatonin,ho-1)': 854,
#   '(telmisartan,adiponectin)': 855,
#   '(pge2,cyp19)': 856,
#   '(forskolin,aromatase)': 857,
#   '(calcitriol,fgf23)': 858,
#   '(glibenclamide,cyp2c9)': 859,
#   '(genistein,bcl-2)': 860,
#   '(rc-160,nnos)': 861,
#   '(amitriptyline,eaat3)': 862,
#   '(fasudil,enos)': 863,
#   '(rosiglitazone,atgl)': 864,
#   '(glibenclamide,cgrp)': 865,
#   '(estradiol,stat3)': 866,
#   '(warfarin,cyp3a4)': 867,
#   '(debrisoquine,cyp2d)': 868,
#   '(mirtazapine,cyp2d)': 869,
#   '(phenylephrine,phospholipase)': 870,
#   '(indomethacin,mucin)': 871,
#   '(dexamethasone,factor-1)': 872,
#   '(forskolin,alpha-msh)': 873,
#   '(gp120,cox-2)': 874,
#   '(naloxone,lhrh)': 875,
#   '(pravastatin,mcp-1)': 876,
#   '(atra,klf4)': 877,
#   '(cyclophosphamide,cyp3a4)': 878,
#   '(glcnac,chia)': 879,
#   '(carrageenan,cox-2)': 880,
#   '(il-2,ccr6)': 881,
#   '(aldosterone,k-ras2a)': 882,
#   '(octreotide,calcitonin)': 883,
#   '(dexamethasone,sp-a)': 884,
#   '(dexamethasone,ugt1a1)': 885,
#   '(g-csf,socs1)': 886,
#   '(clomiphene,lhrh)': 887,
#   '(zolmitriptan,5-ht1b)': 888,
#   '(amitriptyline,p-gp)': 889,
#   '(arsenite,cyp1a1)': 890,
#   '(atorvastatin,resistin)': 891,
#   '(succinylcholine,bche)': 892,
#   '(cisplatin,p-gp)': 893,
#   '(corticosteroids,hips)': 894,
#   '(celecoxib,pc-3)': 895,
#   '(adomet,trna)': 896,
#   '(thyroglobulin,factor-1)': 897,
#   '(lapatinib,cyp3a4)': 898,
#   '(estradiol,comt)': 899,
#   '(zolpidem,cyp3a)': 900,
#   '(gm-csf,phospholipase)': 901,
#   '(alendronate,pthrp)': 902,
#   '(atomoxetine,herg)': 903,
#   '(estradiol,ghrh)': 904,
#   '(simvastatin,cox-2)': 905,
#   '(mifepristone,cox-1)': 906,
#   '(il-2,socs-3)': 907,
#   '(oxytocin,alpha-msh)': 908,
#   '(yohimbine,kallikrein)': 909,
#   '(nadh,nad3)': 910,
#   '(isoflurane,eaat3)': 911,
#   '(pitavastatin,adiponectin)': 912,
#   '(piroxicam,cox-2)': 913,
#   '(cisplatin,msh2)': 914,
#   '(methylprednisolone,fsgs)': 915,
#   '(losartan,cyp3a4)': 916,
#   '(l-ser,3pgdh)': 917,
#   '(dexamethasone,pomc)': 918,
#   '(hyaluronan,glycosyltransferase)': 919,
#   '(cyclosporin,cyp-d)': 920,
#   '(doxycycline,mmp-13)': 921,
#   '(g-csf,interleukin-10)': 922,
#   '(l-dopa,ghrh)': 923,
#   '(prednisolone,p-gp)': 924,
#   '(rapamycin,pc-3)': 925,
#   '(isoproterenol,reticulum)': 926,
#   '(tacrolimus,egfr)': 927,
#   '(aldosterone,bmp-6)': 928,
#   '(atra,aida)': 929,
#   '(verapamil,gastrin)': 930,
#   '(topotecan,abcg2)': 931,
#   '(idarubicin,aida)': 932,
#   '(atorvastatin,apoe)': 933,
#   '(isoflurane,inos)': 934,
#   '(naloxone,adrenocorticotropin)': 935,
#   '(estradiol,dheas)': 936,
#   '(acenocoumarol,cyp2c9)': 937,
#   '(estradiol,resistin)': 938,
#   '(rosiglitazone,resistin)': 939,
#   '(simvastatin,rhob)': 940,
#   '(carboplatin,gm-csf)': 941,
#   '(arsenite,cgl-2)': 942,
#   '(tamoxifen,artn)': 943,
#   '(hydroxyurea,chk1)': 944,
#   '(fluoxetine,darpp-32)': 945,
#   '(paclitaxel,ikappabalpha)': 946,
#   '(gm-csf,cox-2)': 947,
#   '(phosphatidylserine,marcks)': 948,
#   '(il-2,gab2)': 949,
#   '(prostacyclin,cyclooxygenase-1)': 950,
#   '(colchicine,p-gp)': 951,
#   '(fenofibrate,adiponectin)': 952,
#   '(cyclophosphamide,lenograstim)': 953,
#   '(asparaginase,eif2)': 954,
#   '(nifedipine,mnsod)': 955,
#   '(pge2,mmp-2)': 956,
#   '(aldosterone,mcp-1)': 957,
#   '(pentamidine,rgds)': 958,
#   '(clozapine,g-csf)': 959,
#   '(dhea,igf-i)': 960,
#   '(ropivacaine,ml-1)': 961,
#   '(rapamycin,enos)': 962,
#   '(resveratrol,foxo1)': 963,
#   '(estradiol,spinophilin)': 964,
#   '(genistein,pc-3)': 965,
#   '(estradiol,igf-ii)': 966,
#   '(atorvastatin,abcb1)': 967,
#   '(glyburide,niddm)': 968,
#   '(indomethacin,beta-catenin)': 969,
#   '(hyaluronidase,beta-glucuronidase)': 970,
#   '(fenofibrate,apoprotein)': 971,
#   '(resveratrol,nadph)': 972,
#   '(budesonide,cyp3a)': 973,
#   '(mannitol,nadph)': 974,
#   '(gm-csf,cd80)': 975,
#   '(geldanamycin,enos)': 976,
#   '(dexamethasone,osteopontin)': 977,
#   '(rosuvastatin,apob)': 978,
#   '(dexamethasone,runx2)': 979,
#   '(genistein,mucin)': 980,
#   '(doxycycline,vegf)': 981,
#   '(gefitinib,rad51)': 982,
#   '(erlotinib,rad51)': 983,
#   '(phylloquinone,osteocalcin)': 984,
#   '(ru486,gnrh)': 985,
#   '(dhea,gnrh)': 986,
#   '(dexamethasone,igf-i)': 987,
#   '(il-2,cd56)': 988,
#   '(pge2,bcl-2)': 989,
#   '(cisplatin,brca1)': 990,
#   '(berberine,adiponectin)': 991,
#   '(fenofibrate,rbp4)': 992,
#   '(sumatriptan,5-ht1a)': 993,
#   '(estrone,aromatase)': 994,
#   '(metformin,igf-i)': 995,
#   '(ara-c,ifn-alpha)': 996,
#   '(anxiolytics,5-ht1a)': 997,
#   '(trastuzumab,kip1)': 998,
#   '(il-11,survivin)': 999,
#   '(tamoxifen,appd)': 1000,
#   ...},
#  '(norepinephrine,rbp4)': {'(norepinephrine,rbp4)': 1,
#   '(capsaicin,cyp1a1)': 2,
#   '(estradiol,tgf-alpha)': 3,
#   '(resveratrol,survivin)': 4,
#   '(lovastatin,e-selectin)': 5,
#   '(calcitriol,cd14)': 6,
#   '(sulindac,stat3)': 7,
#   '(estradiol,kiss1)': 8,
#   '(estradiol,er-beta)': 9,
#   '(atorvastatin,vegf)': 10,
#   '(atorvastatin,enos)': 11,
#   '(resveratrol,foxo1)': 12,
#   '(atra,klf4)': 13,
#   '(ketamine,hsp70)': 14,
#   '(curcumin,nrf2)': 15,
#   '(il-2,ccr5)': 16,
#   '(pge2,gm-csf)': 17,
#   '(curcumin,mpges-1)': 18,
#   '(tamoxifen,sr-bi)': 19,
#   '(dexamethasone,bcl-x)': 20,
#   '(estradiol,fasl)': 21,
#   '(gefitinib,vegf)': 22,
#   '(fenofibrate,ldlr)': 23,
#   '(oltipraz,cyp1a1)': 24,
#   '(dexamethasone,glut4)': 25,
#   '(melatonin,gnrh)': 26,
#   '(aldosterone,cox-2)': 27,
#   '(naringenin,apob)': 28,
#   '(pge2,vegf)': 29,
#   '(arsenite,vegf)': 30,
#   '(dexamethasone,vegf)': 31,
#   '(tamoxifen,igf-i)': 32,
#   '(aldosterone,pai-1)': 33,
#   '(nelfinavir,vegf)': 34,
#   '(aldosterone,egfr)': 35,
#   '(vasopressin,aqp2)': 36,
#   '(curcumin,gadd153)': 37,
#   '(octreotide,vegf)': 38,
#   '(amitriptyline,gdnf)': 39,
#   '(atra,aqp3)': 40,
#   '(atra,bcl-2)': 41,
#   '(dexamethasone,pai-1)': 42,
#   '(doxorubicin,bcl-2)': 43,
#   '(curcumin,mmp-9)': 44,
#   '(simvastatin,enos)': 45,
#   '(pioglitazone,adiponectin)': 46,
#   '(doxorubicin,skp2)': 47,
#   '(corticosteroids,vegf)': 48,
#   '(resveratrol,atf3)': 49,
#   '(estradiol,igf-ii)': 50,
#   '(sevoflurane,p-selectin)': 51,
#   '(estradiol,vegf)': 52,
#   '(rosiglitazone,atgl)': 53,
#   '(gm-csf,egr-1)': 54,
#   '(propranolol,egr1)': 55,
#   '(atra,cx43)': 56,
#   '(simvastatin,vegf)': 57,
#   '(aldosterone,osteopontin)': 58,
#   '(resveratrol,vegf)': 59,
#   '(atorvastatin,abca1)': 60,
#   '(forskolin,mmp-2)': 61,
#   '(aldosterone,nhe3)': 62,
#   '(berberine,adiponectin)': 63,
#   '(dexamethasone,gm-csf)': 64,
#   '(telmisartan,adiponectin)': 65,
#   '(genistein,enos)': 66,
#   '(atorvastatin,abcb1)': 67,
#   '(pitavastatin,abca1)': 68,
#   '(nifedipine,mnsod)': 69,
#   '(atra,cox-2)': 70,
#   '(pravastatin,abca1)': 71,
#   '(genistein,pai-1)': 72,
#   '(estradiol,gnrh)': 73,
#   '(berberine,pon1)': 74,
#   '(dexamethasone,atrogin-1)': 75,
#   '(resveratrol,egr-1)': 76,
#   '(sildenafil,vegf)': 77,
#   '(cisplatin,bcl-xl)': 78,
#   '(cisplatin,bcl-2)': 79,
#   '(iloprost,vegf)': 80,
#   '(cerivastatin,enos)': 81,
#   '(desipramine,bdnf)': 82,
#   '(6-mercaptopurine,nurr1)': 83,
#   '(bisphosphonates,rankl)': 84,
#   '(dexamethasone,mmp-9)': 85,
#   '(metformin,mdr1)': 86,
#   '(aldosterone,vegf)': 87,
#   '(curcumin,icam-1)': 88,
#   '(pioglitazone,sgk1)': 89,
#   '(arsenite,cox-2)': 90,
#   '(cisplatin,habp1)': 91,
#   '(calcitriol,fgf23)': 92,
#   '(estradiol,cox-2)': 93,
#   '(fk506,cd40l)': 94,
#   '(resveratrol,ho-1)': 95,
#   '(pge2,rankl)': 96,
#   '(hyaluronan,mmp-13)': 97,
#   '(resveratrol,cox-2)': 98,
#   '(melatonin,cry1)': 99,
#   '(troglitazone,vegf)': 100,
#   '(il-2,bcl-2)': 101,
#   '(atra,fr-beta)': 102,
#   '(capsaicin,cgrp)': 103,
#   '(tamoxifen,mcp-1)': 104,
#   '(norepinephrine,thermogenin)': 105,
#   '(doxorubicin,vegf)': 106,
#   '(arsenite,ho-1)': 107,
#   '(flurbiprofen,15-pgdh)': 108,
#   '(isoflurane,eaat3)': 109,
#   '(simvastatin,apom)': 110,
#   '(curcumin,ho-1)': 111,
#   '(capsaicin,cyclooxygenase-2)': 112,
#   '(fenofibrate,pcsk9)': 113,
#   '(bortezomib,skp2)': 114,
#   '(naloxone,gnrh)': 115,
#   '(cilostazol,cd62p)': 116,
#   '(oxytocin,rgs2)': 117,
#   '(meloxicam,vegf)': 118,
#   '(dexamethasone,cd38)': 119,
#   '(rosiglitazone,adiponectin)': 120,
#   '(aldosterone,as160)': 121,
#   '(dexamethasone,edn1)': 122,
#   '(deferoxamine,hif-1alpha)': 123,
#   '(tamoxifen,cyp3a4)': 124,
#   '(il-2,il-22)': 125,
#   '(tamoxifen,heparanase)': 126,
#   '(troglitazone,cox-2)': 127,
#   '(fibrates,sr-bi)': 128,
#   '(colchicine,gm-csf)': 129,
#   '(dexamethasone,cyclooxygenase-2)': 130,
#   '(berberine,mmp-9)': 131,
#   '(sevoflurane,ho-1)': 132,
#   '(genistein,bfgf)': 133,
#   '(nitroprusside,ho-1)': 134,
#   '(simvastatin,ecnos)': 135,
#   '(forskolin,bfgf)': 136,
#   '(secretin,gastrin)': 137,
#   '(dexamethasone,rankl)': 138,
#   '(norepinephrine,gnrh)': 139,
#   '(fk506,icam-1)': 140,
#   '(melatonin,bcl-2)': 141,
#   '(calcitriol,cyp24)': 142,
#   '(estradiol,l-pgds)': 143,
#   '(genistein,bcl-2)': 144,
#   '(cerivastatin,inos)': 145,
#   '(bortezomib,noxa)': 146,
#   '(rosiglitazone,pten)': 147,
#   '(gm-csf,jak2)': 148,
#   '(dexamethasone,muc1)': 149,
#   '(gm-csf,cd86)': 150,
#   '(isoproterenol,mcp-1)': 151,
#   '(mifepristone,cox-1)': 152,
#   '(dexamethasone,nhe3)': 153,
#   '(dexamethasone,mmp-2)': 154,
#   '(celecoxib,vegf)': 155,
#   '(indomethacin,beta-catenin)': 156,
#   '(resveratrol,mmp-9)': 157,
#   '(tamoxifen,vegf)': 158,
#   '(resveratrol,icam-1)': 159,
#   '(atorvastatin,pcsk9)': 160,
#   '(rapamycin,survivin)': 161,
#   '(cisplatin,xiap)': 162,
#   '(lansoprazole,ho-1)': 163,
#   '(forskolin,inos)': 164,
#   '(fluoxetine,bdnf)': 165,
#   '(estrone,aromatase)': 166,
#   '(resveratrol,inos)': 167,
#   '(probucol,ho-1)': 168,
#   '(pge2,cox-2)': 169,
#   '(venlafaxine,bdnf)': 170,
#   '(simvastatin,ho-1)': 171,
#   '(raloxifene,igf-i)': 172,
#   '(ibandronate,rankl)': 173,
#   '(escitalopram,bdnf)': 174,
#   '(dexamethasone,mucin)': 175,
#   '(atorvastatin,tsp-1)': 176,
#   '(omeprazole,gastrin)': 177,
#   '(alendronate,pthrp)': 178,
#   '(estradiol,stat3)': 179,
#   '(cilostazol,pai-1)': 180,
#   '(octreotide,calcitonin)': 181,
#   '(curcumin,hlj1)': 182,
#   '(resveratrol,hif-1alpha)': 183,
#   '(diazoxide,bcl-2)': 184,
#   '(dexamethasone,e-cadherin)': 185,
#   '(carbachol,inositol)': 186,
#   '(aldosterone,sgk1)': 187,
#   '(aldosterone,aqp2)': 188,
#   '(gp120,il-10)': 189,
#   '(abciximab,p-selectin)': 190,
#   '(rosiglitazone,pepck)': 191,
#   '(imatinib,cxcr4)': 192,
#   '(carvedilol,cx43)': 193,
#   '(estradiol,hoxa10)': 194,
#   '(rosiglitazone,vegf)': 195,
#   '(cysteamine,ghrelin)': 196,
#   '(cisplatin,fasl)': 197,
#   '(rosiglitazone,enos)': 198,
#   '(melatonin,nrf2)': 199,
#   '(simvastatin,sr-bi)': 200,
#   '(collagenase,il-1)': 201,
#   '(rifampin,mdr1)': 202,
#   '(resveratrol,mcp-1)': 203,
#   '(rosiglitazone,vldlr)': 204,
#   '(rosiglitazone,glut4)': 205,
#   '(omeprazole,cyp1a1)': 206,
#   '(pge2,cyp19)': 207,
#   '(doxycycline,mmp-2)': 208,
#   '(il-11,stat3)': 209,
#   '(rosiglitazone,nachr)': 210,
#   '(dexamethasone,icam-1)': 211,
#   '(curcumin,inos)': 212,
#   '(curcumin,vegf)': 213,
#   '(atra,eotaxin)': 214,
#   '(staurosporine,gnrh)': 215,
#   '(clonidine,pnmt)': 216,
#   '(atorvastatin,fasl)': 217,
#   '(n-acetylcysteine,cox-2)': 218,
#   '(dexamethasone,cyp3a)': 219,
#   '(estradiol,cyp1b1)': 220,
#   '(rapamycin,inos)': 221,
#   '(nifedipine,mmp-2)': 222,
#   '(losartan,adiponectin)': 223,
#   '(hyaluronan,glycosyltransferase)': 224,
#   '(pge2,cox-1)': 225,
#   '(gp120,nf-kappab)': 226,
#   '(estradiol,cgrp)': 227,
#   '(il-2,socs-3)': 228,
#   '(troglitazone,cyp1a1)': 229,
#   '(resveratrol,cyclooxygenase-2)': 230,
#   '(il-2,pthrp)': 231,
#   '(estradiol,sf-1)': 232,
#   '(estradiol,apoe)': 233,
#   '(phenylephrine,inositol)': 234,
#   '(memantine,bdnf)': 235,
#   '(cisplatin,caspase-3)': 236,
#   '(oltipraz,pai-1)': 237,
#   '(diazepam,egr-1)': 238,
#   '(triiodothyronine,apob)': 239,
#   '(dexamethasone,myostatin)': 240,
#   '(hydrocortisone,endothelin-1)': 241,
#   '(il-2,perforin)': 242,
#   '(resveratrol,erbb2)': 243,
#   '(budesonide,vegf)': 244,
#   '(gemfibrozil,pai-1)': 245,
#   '(genistein,fmlp)': 246,
#   '(tamoxifen,ki-67)': 247,
#   '(aldosterone,alpha-enac)': 248,
#   '(minocycline,bcl-2)': 249,
#   '(carbachol,gastrin)': 250,
#   '(gefitinib,erbb3)': 251,
#   '(nadh,gapdh)': 252,
#   '(propofol,enos)': 253,
#   '(clopidogrel,p-selectin)': 254,
#   '(cyclosporin,inos)': 255,
#   '(simvastatin,cyr61)': 256,
#   '(octreotide,igfbp-1)': 257,
#   '(propofol,hif-1)': 258,
#   '(curcumin,blys)': 259,
#   '(minocycline,5-lox)': 260,
#   '(estradiol,creb)': 261,
#   '(hemin,ho-1)': 262,
#   '(indomethacin,15-pgdh)': 263,
#   '(resveratrol,cyp1b1)': 264,
#   '(aldosterone,g6pd)': 265,
#   '(propofol,bcl-2)': 266,
#   '(dexamethasone,pnmt)': 267,
#   '(estradiol,enos)': 268,
#   '(isoflurane,ho-1)': 269,
#   '(forskolin,aromatase)': 270,
#   '(aldosterone,alpha-msh)': 271,
#   '(dexamethasone,sp-a)': 272,
#   '(celecoxib,vegf-c)': 273,
#   '(atorvastatin,adiponectin)': 274,
#   '(phenylephrine,sirt1)': 275,
#   '(mitomycin,reca)': 276,
#   '(fenofibrate,rbp4)': 277,
#   '(ceftriaxone,glt-1)': 278,
#   '(clonidine,beta-endorphin)': 279,
#   '(paclitaxel,bcl-2)': 280,
#   '(haloperidol,kallikrein)': 281,
#   '(bromocriptine,pomc)': 282,
#   '(ritonavir,cd36)': 283,
#   '(resveratrol,pkm2)': 284,
#   '(pravastatin,lox-1)': 285,
#   '(rapamycin,pai-1)': 286,
#   '(dhea,il-10)': 287,
#   '(pge2,timp-1)': 288,
#   '(resveratrol,enos)': 289,
#   '(haloperidol,alpha-msh)': 290,
#   '(estradiol,bcl-2)': 291,
#   '(metformin,pepck)': 292,
#   '(propranolol,gastrin)': 293,
#   '(dexamethasone,inos)': 294,
#   '(dexamethasone,aromatase)': 295,
#   '(dexamethasone,gastrin)': 296,
#   '(celecoxib,nag-1)': 297,
#   '(curcumin,mmp-2)': 298,
#   '(pentagastrin,calcitonin)': 299,
#   '(forskolin,vegf)': 300,
#   '(deferoxamine,hif-1)': 301,
#   '(aprotinin,thrombomodulin)': 302,
#   '(isoniazid,cyp2e1)': 303,
#   '(dexamethasone,ampk)': 304,
#   '(fibrates,pltp)': 305,
#   '(naltrexone,pomc)': 306,
#   '(simvastatin,mmp-9)': 307,
#   '(indomethacin,survivin)': 308,
#   '(l-glutamine,ppargamma)': 309,
#   '(fk506,igf-i)': 310,
#   '(g-csf,psgl-1)': 311,
#   '(lovastatin,inos)': 312,
#   '(montelukast,inos)': 313,
#   '(dexamethasone,cyp3a4)': 314,
#   '(rifampin,cyp3a4)': 315,
#   '(propofol,beta2)': 316,
#   '(estradiol,igfbp-2)': 317,
#   '(dexamethasone,resistin)': 318,
#   '(indomethacin,nag-1)': 319,
#   '(pge2,aromatase)': 320,
#   '(resveratrol,nag-1)': 321,
#   '(atorvastatin,mcp-1)': 322,
#   '(pge2,hsp27)': 323,
#   '(octreotide,gastrin)': 324,
#   '(secretin,calcitonin)': 325,
#   '(sorafenib,mcl-1)': 326,
#   '(imipramine,bdnf)': 327,
#   '(estradiol,ghrh)': 328,
#   '(dexamethasone,il-5)': 329,
#   '(forskolin,proenkephalin)': 330,
#   '(dexamethasone,gnrh)': 331,
#   '(olanzapine,bdnf)': 332,
#   '(mifepristone,gnrh)': 333,
#   '(oxytocin,alpha-msh)': 334,
#   '(oxytocin,gnrh)': 335,
#   '(pge2,inos)': 336,
#   '(rapamycin,ho-1)': 337,
#   '(vasopressin,hsp27)': 338,
#   '(aldosterone,adiponectin)': 339,
#   '(metformin,aromatase)': 340,
#   '(vasopressin,aquaporin-2)': 341,
#   '(g-csf,stat3)': 342,
#   '(hyaluronan,has3)': 343,
#   '(staurosporine,timp-1)': 344,
#   '(cyclophosphamide,cyp3a4)': 345,
#   '(dexamethasone,ugt1a1)': 346,
#   '(glcnac,chia)': 347,
#   '(g-csf,socs1)': 348,
#   '(carrageenan,cox-2)': 349,
#   '(il-2,ccr6)': 350,
#   '(aldosterone,k-ras2a)': 351,
#   '(curcumin,cftr)': 352,
#   '(desferrioxamine,hif-1alpha)': 353,
#   '(dexamethasone,eotaxin)': 354,
#   '(troglitazone,adiponectin)': 355,
#   '(rifampin,cyp3a)': 356,
#   '(carbachol,egr-1)': 357,
#   '(aripiprazole,bdnf)': 358,
#   '(gm-csf,mt1-mmp)': 359,
#   '(probenecid,bfgf)': 360,
#   '(genistein,her2)': 361,
#   '(pegvisomant,igf-i)': 362,
#   '(genistein,cox-2)': 363,
#   '(isoprenaline,pepck)': 364,
#   '(colchicine,il-1)': 365,
#   '(dexamethasone,ppar-gamma)': 366,
#   '(dexamethasone,ghrh)': 367,
#   '(cimetidine,e-selectin)': 368,
#   '(paclitaxel,vegf)': 369,
#   '(dexamethasone,parp)': 370,
#   '(dexamethasone,cd40l)': 371,
#   '(doxorubicin,parp)': 372,
#   '(oltipraz,gsta2)': 373,
#   '(metformin,pten)': 374,
#   '(gm-csf,phospholipase)': 375,
#   '(donepezil,igf-i)': 376,
#   '(arsenite,hsp70)': 377,
#   '(estradiol,hsp90)': 378,
#   '(triamcinolone,vegf)': 379,
#   '(curcumin,ctgf)': 380,
#   '(betaine,nf-kappab)': 381,
#   '(melatonin,beta-endorphin)': 382,
#   '(fibrates,mdr2)': 383,
#   '(minocycline,hmgb1)': 384,
#   '(troglitazone,kip1)': 385,
#   '(acarbose,glp-1)': 386,
#   '(streptozocin,niddm)': 387,
#   '(carbachol,mucin)': 388,
#   '(vasopressin,atriopeptin)': 389,
#   '(melatonin,nf-kappab)': 390,
#   '(atra,mef2c)': 391,
#   '(cisapride,herg)': 392,
#   '(dexamethasone,rantes)': 393,
#   '(hyaluronan,erbb2)': 394,
#   '(berberine,glp-1)': 395,
#   '(bortezomib,ikappabalpha)': 396,
#   '(lovastatin,pten)': 397,
#   '(tamoxifen,survivin)': 398,
#   '(sulindac,egr-1)': 399,
#   '(forskolin,pomc)': 400,
#   '(chloramphenicol,cyp1a1)': 401,
#   '(g-csf,mmp-2)': 402,
#   '(estradiol,osteocalcin)': 403,
#   '(indomethacin,mcp-1)': 404,
#   '(sunitinib,hif-1alpha)': 405,
#   '(haloperidol,vegf)': 406,
#   '(estradiol,ppargamma)': 407,
#   '(forskolin,pai-1)': 408,
#   '(hydrocortisone,pai-1)': 409,
#   '(nitroprusside,enos)': 410,
#   '(pge2,il-10)': 411,
#   '(metyrapone,cyp3a)': 412,
#   '(l-dopa,fosb)': 413,
#   '(il-2,bcl1)': 414,
#   '(aldosterone,ace2)': 415,
#   '(cisplatin,hipk2)': 416,
#   '(n-acetylcysteine,ho-1)': 417,
#   '(telmisartan,abca1)': 418,
#   '(dexamethasone,cyp2e1)': 419,
#   '(isoprenaline,mmp-9)': 420,
#   '(dexamethasone,5-lipoxygenase)': 421,
#   '(forskolin,cox-2)': 422,
#   '(artemisinin,cyp2c19)': 423,
#   '(cyclosporin,cd28)': 424,
#   '(pge2,ifn-gamma)': 425,
#   '(celecoxib,tcf-1)': 426,
#   '(prostacyclin,cyclooxygenase-1)': 427,
#   '(perindopril,vegf)': 428,
#   '(cyclosporine,hnf4alpha)': 429,
#   '(rifampin,mrp2)': 430,
#   '(cisplatin,mkp-1)': 431,
#   '(dexamethasone,muc5ac)': 432,
#   '(atra,dhand)': 433,
#   '(meth,nnos)': 434,
#   '(vasopressin,inositol)': 435,
#   '(primaquine,g6pd)': 436,
#   '(nitroprusside,inos)': 437,
#   '(pyridostigmine,igf-i)': 438,
#   '(fenofibrate,paraoxonase)': 439,
#   '(leflunomide,nf-kappab)': 440,
#   '(ciclesonide,mcp-1)': 441,
#   '(metformin,adiponectin)': 442,
#   '(lubiprostone,cftr)': 443,
#   '(oxytocin,lhrh)': 444,
#   '(clomiphene,lhrh)': 445,
#   '(aldosterone,enacalpha)': 446,
#   '(forskolin,nachr)': 447,
#   '(yohimbine,kallikrein)': 448,
#   '(theophylline,hdac)': 449,
#   '(carvedilol,il-10)': 450,
#   '(dexamethasone,rasd1)': 451,
#   '(phenylephrine,egfr)': 452,
#   '(curcumin,cox-2)': 453,
#   '(bortezomib,survivin)': 454,
#   '(curcumin,egr-1)': 455,
#   '(gemcitabine,nfkappab)': 456,
#   '(daunorubicin,igf-i)': 457,
#   '(paclitaxel,hsp27)': 458,
#   '(nadh,oxidoreductase)': 459,
#   '(paroxetine,bdnf)': 460,
#   '(carbamazepine,eaat3)': 461,
#   '(gm-csf,mcp-1)': 462,
#   '(atra,cox-1)': 463,
#   '(dexamethasone,il-1)': 464,
#   '(tamoxifen,shbg)': 465,
#   '(rosiglitazone,adipor2)': 466,
#   '(cimetidine,gastrin)': 467,
#   '(pioglitazone,ctgf)': 468,
#   '(dexamethasone,l-selectin)': 469,
#   '(atra,trkb)': 470,
#   '(pge2,igfbp-5)': 471,
#   '(isoproterenol,reticulum)': 472,
#   '(tamoxifen,phospholipase)': 473,
#   '(telmisartan,enos)': 474,
#   '(pge2,icam-1)': 475,
#   '(atra,tsp-1)': 476,
#   '(hyaluronan,has2)': 477,
#   '(il-2,nkg2d)': 478,
#   '(carbachol,phospholipase)': 479,
#   '(dexamethasone,mcp-1)': 480,
#   '(isoproterenol,calcitonin)': 481,
#   '(efavirenz,cyp3a4)': 482,
#   '(corticosteroids,aqp1)': 483,
#   '(rosiglitazone,il-1ra)': 484,
#   '(cisplatin,nf-kappab)': 485,
#   '(pge2,il-27)': 486,
#   '(naringenin,tslp)': 487,
#   '(genistein,sulfotransferase)': 488,
#   '(cilostazol,mcp-1)': 489,
#   '(irinotecan,egfr)': 490,
#   '(pge2,aqp2)': 491,
#   '(nateglinide,glp-1)': 492,
#   '(fk506,bcl-2)': 493,
#   '(simvastatin,pparalpha)': 494,
#   '(dexamethasone,mkp-1)': 495,
#   '(imatinib,vegf)': 496,
#   '(il-2,stat5)': 497,
#   '(il-2,hdac1)': 498,
#   '(arsenite,arsa)': 499,
#   '(indomethacin,mucin)': 500,
#   '(cysteamine,gastrin)': 501,
#   '(il-2,m-csf)': 502,
#   '(genistein,sp-a)': 503,
#   '(pioglitazone,mmp-9)': 504,
#   '(paclitaxel,ap-1)': 505,
#   '(benzbromarone,adiponectin)': 506,
#   '(rapamycin,enos)': 507,
#   '(dexamethasone,il-13)': 508,
#   '(rapamycin,vegf)': 509,
#   '(rifabutin,cyp3a)': 510,
#   '(lansoprazole,bfgf)': 511,
#   '(rosiglitazone,pai-1)': 512,
#   '(troglitazone,pai-1)': 513,
#   '(g-csf,cxcr4)': 514,
#   '(capsaicin,cox-2)': 515,
#   '(il-2,p-selectin)': 516,
#   '(arsenite,ang-1)': 517,
#   '(dexamethasone,igfbp-1)': 518,
#   '(atra,nf-kappab)': 519,
#   '(estradiol,ho-1)': 520,
#   '(norepinephrine,inositol)': 521,
#   '(fasudil,enos)': 522,
#   '(forskolin,igfbp-3)': 523,
#   '(isoproterenol,gastrin)': 524,
#   '(g-csf,mmp-9)': 525,
#   '(atra,ddah)': 526,
#   '(cisplatin,vegf)': 527,
#   '(curcumin,bcl-2)': 528,
#   '(indomethacin,crth2)': 529,
#   '(hyaluronan,aggrecan)': 530,
#   '(pge2,mpges-1)': 531,
#   '(cisplatin,ho-1)': 532,
#   '(propranolol,vegf)': 533,
#   '(genistein,cftr)': 534,
#   '(genistein,mcp-1)': 535,
#   '(rosiglitazone,tlr4)': 536,
#   '(aldosterone,k-ras)': 537,
#   '(pioglitazone,lox-1)': 538,
#   '(procainamide,napa)': 539,
#   '(indomethacin,mmp-2)': 540,
#   '(voglibose,glp-1)': 541,
#   '(gemcitabine,vegf)': 542,
#   '(pge2,bfgf)': 543,
#   '(melatonin,ho-1)': 544,
#   '(estradiol,igf-i)': 545,
#   '(il-2,foxp3)': 546,
#   '(isoproterenol,mucin)': 547,
#   '(ropinirole,zif-268)': 548,
#   '(alendronate,vegf)': 549,
#   '(simvastatin,pai-1)': 550,
#   '(ndga,nrf2)': 551,
#   '(forskolin,sf-1)': 552,
#   '(metformin,ampk)': 553,
#   '(candesartan,vegf)': 554,
#   '(il-2,stat4)': 555,
#   '(genistein,vegf)': 556,
#   '(fibrates,apoc-iii)': 557,
#   '(doxycycline,mmp-3)': 558,
#   '(dexamethasone,ifn-gamma)': 559,
#   '(pge2,ml-1)': 560,
#   '(dexamethasone,beta-induced)': 561,
#   '(dexamethasone,sp-b)': 562,
#   '(metformin,glut1)': 563,
#   '(theophylline,gm-csf)': 564,
#   '(melatonin,aanat)': 565,
#   '(trastuzumab,vegf)': 566,
#   '(capsaicin,tnox)': 567,
#   '(dexamethasone,il-1ra)': 568,
#   '(riluzole,hsf1)': 569,
#   '(forskolin,gnrh)': 570,
#   '(vasopressin,calmodulin)': 571,
#   '(chloramphenicol,inos)': 572,
#   '(fluvastatin,inos)': 573,
#   '(fentanyl,ml-1)': 574,
#   '(fluvastatin,enos)': 575,
#   '(methotrexate,etanercept)': 576,
#   '(cisplatin,cited2)': 577,
#   '(paclitaxel,caspase-3)': 578,
#   '(dexamethasone,fasl)': 579,
#   '(tamoxifen,jnk1)': 580,
#   '(rabeprazole,mucin)': 581,
#   '(fk506,ifn-gamma)': 582,
#   '(vinblastine,cyp3a4)': 583,
#   '(tranilast,bfgf)': 584,
#   '(berberine,ampk)': 585,
#   '(irbesartan,mcp-1)': 586,
#   '(genistein,pi-9)': 587,
#   '(genistein,il-10)': 588,
#   '(arsenite,hsp72)': 589,
#   '(calcitriol,fgf-23)': 590,
#   '(octreotide,ghrelin)': 591,
#   '(dexamethasone,iapp)': 592,
#   '(corticosteroids,adrenocorticotropin)': 593,
#   '(rosiglitazone,fgf-21)': 594,
#   '(clofibrate,cyp2e1)': 595,
#   '(pravastatin,mcp-1)': 596,
#   '(il-2,il-17)': 597,
#   '(hemin,cyp1a1)': 598,
#   '(rapamycin,rapa)': 599,
#   '(metformin,pai-1)': 600,
#   '(berberine,cox-2)': 601,
#   '(lmwh,tfpi)': 602,
#   '(dexamethasone,kallikrein)': 603,
#   '(simvastatin,cox-2)': 604,
#   '(milnacipran,bdnf)': 605,
#   '(il-2,inositol)': 606,
#   '(il-2,lymphokine)': 607,
#   '(atorvastatin,ldlc)': 608,
#   '(valsartan,adiponectin)': 609,
#   '(arsenite,parp)': 610,
#   '(erythromycin,nadph)': 611,
#   '(simvastatin,mcp-1)': 612,
#   '(fenofibrate,enos)': 613,
#   '(pge2,stat3)': 614,
#   '(isoproterenol,phospholipase)': 615,
#   '(cisplatin,plaa)': 616,
#   '(imatinib,cox-2)': 617,
#   '(clopidogrel,cyp3a4)': 618,
#   '(methylprednisolone,il-10)': 619,
#   '(il-2,vegf)': 620,
#   '(rasagiline,bcl-2)': 621,
#   '(bromocriptine,gnrh)': 622,
#   '(curcumin,npc1l1)': 623,
#   '(terbutaline,gastrin)': 624,
#   '(topiramate,cgrp)': 625,
#   '(budesonide,icam-1)': 626,
#   '(iloprost,ctgf)': 627,
#   '(nitroprusside,lhrh)': 628,
# ...
#   '(aldosterone,as160)': 462,
#   '(g-csf,filgrastim)': 463,
#   '(filgrastim,g-csf)': 464,
#   '(halothane,calmodulin)': 465,
#   '(tamoxifen,mcp-1)': 466,
#   '(lovastatin,pten)': 467,
#   '(il-1ra,il1rn)': 468,
#   '(doxorubicin,bcl-2)': 469,
#   '(vincristine,mrp1)': 470,
#   '(buspirone,5-ht1a)': 471,
#   '(vatalanib,vegf)': 472,
#   '(perindopril,vegf)': 473,
#   '(delavirdine,cyp3a4)': 474,
#   '(raloxifene,igf-i)': 475,
#   '(propafenone,cyp2d6)': 476,
#   '(bupropion,cyp2b6)': 477,
#   '(thioridazine,calmodulin)': 478,
#   '(vasopressin,beta-endorphin)': 479,
#   '(n-acetylcysteine,nadph)': 480,
#   '(dexamethasone,aromatase)': 481,
#   '(topotecan,bcrp)': 482,
#   '(aldosterone,per1)': 483,
#   '(taurine,kallikrein)': 484,
#   '(paclitaxel,nfkappab)': 485,
#   '(dexamethasone,ifn-gamma)': 486,
#   '(estradiol,creb)': 487,
#   '(pge2,ml-1)': 488,
#   '(ribavirin,eif4e)': 489,
#   '(losartan,cyp2c9)': 490,
#   '(tolcapone,comt)': 491,
#   '(amitriptyline,trka)': 492,
#   '(colchicine,p-gp)': 493,
#   '(fk506,nf-kappab)': 494,
#   '(capsaicin,pi3k)': 495,
#   '(aldosterone,dheas)': 496,
#   '(g-csf,il-1)': 497,
#   '(quinidine,herg)': 498,
#   '(metformin,alpha-glucosidase)': 499,
#   '(aripiprazole,5-ht1a)': 500,
#   '(forskolin,raf-1)': 501,
#   '(etoposide,brca1)': 502,
#   '(taurine,glyrs)': 503,
#   '(il-2,g-csf)': 504,
#   '(forskolin,nachr)': 505,
#   '(g-csf,il-5)': 506,
#   '(hyaluronan,adiponectin)': 507,
#   '(carbachol,cgrp)': 508,
#   '(metyrapone,adrenocorticotropin)': 509,
#   '(doxazosin,pc-3)': 510,
#   '(tcgf,lymphokine)': 511,
#   '(il-2,cd86)': 512,
#   '(il-2,cd80)': 513,
#   '(clopidogrel,cyp2c19)': 514,
#   '(sunitinib,abcb1)': 515,
#   '(zileuton,leukotriene)': 516,
#   '(melphalan,amyloidosis)': 517,
#   '(troglitazone,cyp3a)': 518,
#   '(pge2,cox-2)': 519,
#   '(pioglitazone,ampk)': 520,
#   '(pge2,cox-1)': 521,
#   '(fk506,il-5)': 522,
#   '(vasopressin,v1br)': 523,
#   '(tacrolimus,fkbp-12)': 524,
#   '(paclitaxel,cox-2)': 525,
#   '(raloxifene,menin)': 526,
#   '(genistein,pc-3)': 527,
#   '(corticotropin,adrenocorticotropin)': 528,
#   '(coumarin,cyp2a6)': 529,
#   '(fk506,caspase-3)': 530,
#   '(colchicine,il-1)': 531,
#   '(artemisinin,cdk2)': 532,
#   '(bleomycin,cox-2)': 533,
#   '(artemisinin,cdk4)': 534,
#   '(minocycline,caspase-3)': 535,
#   '(hpth,pthrp)': 536,
#   '(octreotide,igf-i)': 537,
#   '(pge2,igf-i)': 538,
#   '(gp120,icam-1)': 539,
#   '(vorinostat,hdac)': 540,
#   '(prostacyclin,calcitonin)': 541,
#   '(isoflurane,lfa-1)': 542,
#   '(paroxetine,cyp2d6)': 543,
#   '(coxibs,cox-2)': 544,
#   '(coxibs,cox-1)': 545,
#   '(diclofenac,ugt2b7)': 546,
#   '(atra,bcl-2)': 547,
#   '(hemin,ho-2)': 548,
#   '(arsenite,cyp3a4)': 549,
#   '(hemin,ho-1)': 550,
#   '(etanercept,il-1)': 551,
#   '(il-2,lfa-1)': 552,
#   '(cisplatin,cd44)': 553,
#   '(urokinase,pai-1)': 554,
#   '(urokinase,kallikrein)': 555,
#   '(urokinase,pai-2)': 556,
#   '(ru486,aromatase)': 557,
#   '(dexamethasone,gastrin)': 558,
#   '(capsaicin,trpv1)': 559,
#   '(creatine,transamidinase)': 560,
#   '(vildagliptin,dpp-4)': 561,
#   '(sulindac,survivin)': 562,
#   '(rosiglitazone,mmp-9)': 563,
#   '(triiodothyronine,shbg)': 564,
#   '(resveratrol,fasl)': 565,
#   '(cyclophosphamide,srbc)': 566,
#   '(carvedilol,sapk)': 567,
#   '(pge2,il-1ra)': 568,
#   '(troglitazone,niddm)': 569,
#   '(atra,irs-1)': 570,
#   '(zonisamide,cyp3a4)': 571,
#   '(rapamycin,aicar)': 572,
#   '(axitinib,vegf)': 573,
#   '(norepinephrine,catechol-o-methyltransferase)': 574,
#   '(pge2,mpges)': 575,
#   '(dexamethasone,cpla2)': 576,
#   '(genistein,icam-1)': 577,
#   '(metoprolol,copd)': 578,
#   '(oxytocin,sf-1)': 579,
#   '(bezafibrate,l-fabp)': 580,
#   '(lovastatin,icam-1)': 581,
#   '(estradiol,hsp90)': 582,
#   '(pimozide,gnrh)': 583,
#   '(scopolamine,scop)': 584,
#   '(curcumin,hlj1)': 585,
#   '(cisplatin,g-csf)': 586,
#   '(cyclosporine,hnf4alpha)': 587,
#   '(fluorescein,cd14)': 588,
#   '(carvedilol,il-10)': 589,
#   '(methylprednisolone,g-csf)': 590,
#   '(cholestyramine,acat)': 591,
#   '(genistein,sulfotransferase)': 592,
#   '(moclobemide,mao-b)': 593,
#   '(dexamethasone,mkp-1)': 594,
#   '(gm-csf,cox-2)': 595,
#   '(simvastatin,rhoa)': 596,
#   '(simvastatin,rhob)': 597,
#   '(neostigmine,cholinesterase)': 598,
#   '(4-methylpyrazole,cyp2e1)': 599,
#   '(melphalan,hilp)': 600,
#   '(moclobemide,mao-a)': 601,
#   '(mivacurium,cholinesterase)': 602,
#   '(resveratrol,survivin)': 603,
#   '(risperidone,cyp3a4)': 604,
#   '(aldosterone,mcp-1)': 605,
#   '(fk-506,fkbp12)': 606,
#   '(oltipraz,pai-1)': 607,
#   '(mannitol,m6pr)': 608,
#   '(il-2,cd30)': 609,
#   '(tamoxifen,er-beta)': 610,
#   '(fibrates,ppar)': 611,
#   '(phenformin,ampk)': 612,
#   '(perazine,cyp1a2)': 613,
#   '(il-2,cd23)': 614,
#   '(estradiol,gnrh-r)': 615,
#   '(il-2,cd25)': 616,
#   '(il-1rn,il-1b)': 617,
#   '(il-2,cd28)': 618,
#   '(rolipram,pde4)': 619,
#   '(carnitine,crat)': 620,
#   '(doxepin,cyp2d6)': 621,
#   '(resveratrol,xbp1)': 622,
#   '(chlorpromazine,herg)': 623,
#   '(ticagrelor,p2y12)': 624,
#   '(bambuterol,bche)': 625,
#   '(vasopressin,lhrh)': 626,
#   '(nitrofurantoin,bcrp)': 627,
#   '(ketoprofen,cox-1)': 628,
#   '(cisplatin,cmoat)': 629,
#   '(estradiol,shbg)': 630,
#   '(varenicline,icer)': 631,
#   '(nifedipine,cyp3a)': 632,
#   '(adomet,trna)': 633,
#   '(aldosterone,sf-1)': 634,
#   '(gm-csf,ml-1)': 635,
#   '(itraconazole,cyp3a4)': 636,
#   '(doxorubicin,tace)': 637,
#   '(indomethacin,mmp-2)': 638,
#   '(propofol,ugt1a9)': 639,
#   '(pgi2,ml-1)': 640,
#   '(bortezomib,noxa)': 641,
#   '(resveratrol,bcl-2)': 642,
#   '(indomethacin,mmp-9)': 643,
#   '(celecoxib,egfr)': 644,
#   '(indomethacin,pla2)': 645,
#   '(celecoxib,cyclooxygenase-2)': 646,
#   '(clopidogrel,p2y12)': 647,
#   '(octreotide,igfbp-1)': 648,
#   '(pge2,igfbp-5)': 649,
#   '(ibandronate,rankl)': 650,
#   '(rc-160,nnos)': 651,
#   '(simvastatin,bcl-2)': 652,
#   '(curcumin,irak)': 653,
#   '(dexamethasone,gamma-glutamyltransferase)': 654,
#   '(chlorambucil,amyloidosis)': 655,
#   '(il-1ra,il-10)': 656,
#   '(methotrexate,mrp2)': 657,
#   '(il-2,cd40)': 658,
#   '(cimetidine,cyp1a2)': 659,
#   '(sorafenib,mcl-1)': 660,
#   '(prostacyclin,pgl2)': 661,
#   '(il-2,ap-1)': 662,
#   '(paroxetine,bdnf)': 663,
#   '(aldosterone,leu-enkephalin)': 664,
#   '(hyaluronan,inter-alpha-trypsin)': 665,
#   '(methotrexate,mrp4)': 666,
#   '(imatinib,cxcr4)': 667,
#   '(gm-csf,il-1ra)': 668,
#   '(n-acetyl-d-glucosamine,lectin)': 669,
#   '(tamoxifen,hoxb13)': 670,
#   '(everolimus,nets)': 671,
#   '(prostacyclin,pgis)': 672,
#   '(selegiline,cyp2b6)': 673,
#   '(il-2,bfgf)': 674,
#   '(clozapine,cyp1a2)': 675,
#   '(il-2,cd71)': 676,
#   '(misoprostol,cox-2)': 677,
#   '(ivermectin,p-gp)': 678,
#   '(exenatide,dpp-4)': 679,
#   '(dexamethasone,ppar-gamma)': 680,
#   '(pgi2,cox-2)': 681,
#   '(dexamethasone,cyp3a4)': 682,
#   '(il-2,cd69)': 683,
#   '(aldosterone,ctrp1)': 684,
#   '(eserine,cholinesterase)': 685,
#   '(sevoflurane,caspase-3)': 686,
#   '(everolimus,cyp3a)': 687,
#   '(tamoxifen,survivin)': 688,
#   '(g-csf,csf3r)': 689,
#   '(g-csf,cd11b)': 690,
#   '(doxorubicin,nadph)': 691,
#   '(clofibrate,ppar)': 692,
#   '(cytarabine,g-csf)': 693,
#   '(nadh,reticulum)': 694,
#   '(atorvastatin,nf-kappab)': 695,
#   '(rosiglitazone,pten)': 696,
#   '(hyaluronidase,ph-20)': 697,
#   '(fluorescein,cd45)': 698,
#   '(il-2,cd56)': 699,
#   '(octreotide,ghrelin)': 700,
#   '(il-2,cd54)': 701,
#   '(lansoprazole,cyp2c19)': 702,
#   '(creatine,igf-i)': 703,
#   '(sunitinib,pdgfr)': 704,
#   '(cyclophosphamide,ifn-gamma)': 705,
#   '(vasopressin,kallikrein)': 706,
#   '(trimethoprim,nadph)': 707,
#   '(creatine,glut4)': 708,
#   '(bortezomib,cip2a)': 709,
#   '(duloxetine,cyp2d6)': 710,
#   '(propranolol,egr1)': 711,
#   '(fk506,rotamase)': 712,
#   '(chlorpromazine,calmodulin)': 713,
#   '(hydralazine,ssao)': 714,
#   '(atra,gnt-v)': 715,
#   '(phenytoin,cyp2c19)': 716,
#   '(amd3100,cxcl12)': 717,
#   '(capsaicin,trpa1)': 718,
#   '(forskolin,gnrh)': 719,
#   '(indomethacin,akr1c3)': 720,
#   '(prednisolone,p-gp)': 721,
#   '(dexamethasone,eotaxin)': 722,
#   '(cyclosporin,cyp-d)': 723,
#   '(berberine,mmp-9)': 724,
#   '(betaine,igf-i)': 725,
#   '(capsaicin,calcitonin)': 726,
#   '(celecoxib,cox-1)': 727,
#   '(celecoxib,cox-2)': 728,
#   '(naltrexone,beta-endorphin)': 729,
#   '(temozolomide,top2a)': 730,
#   '(aminoglutethimide,p450scc)': 731,
#   '(abacavir,p-gp)': 732,
#   '(triacetyloleandomycin,cyp3a)': 733,
#   '(haloperidol,cyp3a4)': 734,
#   '(rosiglitazone,vldlr)': 735,
#   '(isoprenaline,mmp-9)': 736,
#   '(bisphosphonates,rankl)': 737,
#   '(clozapine,5-ht1c)': 738,
#   '(forskolin,cftr)': 739,
#   '(rapamycin,ogg1)': 740,
#   '(clozapine,5-ht1a)': 741,
#   '(glyburide,abca1)': 742,
#   '(fluvoxamine,cyp2d6)': 743,
#   '(simvastatin,statin)': 744,
#   '(carboplatin,vegf)': 745,
#   '(indomethacin,beta-catenin)': 746,
#   '(triflusal,nf-kappab)': 747,
#   '(estradiol,spinophilin)': 748,
#   '(metformin,mtor)': 749,
#   '(lovastatin,e-selectin)': 750,
#   '(naringenin,pon1)': 751,
#   '(rolipram,cd11b)': 752,
#   '(rosiglitazone,cyp3a4)': 753,
#   '(sevoflurane,p-selectin)': 754,
#   '(celecoxib,nfkappab)': 755,
#   '(rosiglitazone,ppar-gamma)': 756,
#   '(gm-csf,rankl)': 757,
#   '(colchicine,mefv)': 758,
#   '(bleomycin,ifn-beta)': 759,
#   '(pge2,inositol)': 760,
#   '(idarubicin,aida)': 761,
#   '(quinacrine,pla2)': 762,
#   '(arsenite,ikappabalpha)': 763,
#   '(doxorubicin,mtor)': 764,
#   '(prednisone,cholinesterase)': 765,
#   '(topotecan,ube3a)': 766,
#   '(prostacyclin,cyp8a1)': 767,
#   '(pge2,socs3)': 768,
#   '(fibrates,statin)': 769,
#   '(fluoroquinolones,copd)': 770,
#   '(estrone,udp-glucuronosyltransferase)': 771,
#   '(corticotropin,pro-opiomelanocortin)': 772,
#   '(l-leucine,lat1)': 773,
#   '(celecoxib,nag-1)': 774,
#   '(candesartan,pai-1)': 775,
#   '(genistein,phospholipase)': 776,
#   '(hyaluronan,habp)': 777,
#   '(risedronate,fpps)': 778,
#   '(etoposide,cyr61)': 779,
#   '(rapamycin,pc-3)': 780,
#   '(troglitazone,vegf)': 781,
#   '(panitumumab,kras)': 782,
#   '(hydroxyurea,il-13)': 783,
#   '(gm-csf,stat1)': 784,
#   '(gm-csf,stat3)': 785,
#   '(lmwh,tfpi)': 786,
#   '(cisplatin,habp1)': 787,
#   '(curcumin,nrf2)': 788,
#   '(diazepam,egr-1)': 789,
#   '(docetaxel,bcl-2)': 790,
#   '(glucosamine,lectin)': 791,
#   '(gemcitabine,mir-21)': 792,
#   '(cyclosporin,cyp3a)': 793,
#   '(phosphatidylserine,marcks)': 794,
#   '(pge2,inos)': 795,
#   '(thymalfasin,tace)': 796,
#   '(gm-csf,lymphokine)': 797,
#   '(alfentanil,cyp3a5)': 798,
#   '(alfentanil,cyp3a4)': 799,
#   '(sulfaphenazole,cyp2c9)': 800,
#   '(pravastatin,lox-1)': 801,
#   '(troglitazone,adiponectin)': 802,
#   '(il-11,stat3)': 803,
#   '(genistein,fgf-2)': 804,
#   '(clozapine,tspo)': 805,
#   '(sulfonamides,dhps)': 806,
#   '(estradiol,igf-ii)': 807,
#   '(carnitine,acyltransferase)': 808,
#   '(naloxone,beta-endorphin)': 809,
#   '(oxytocin,rgs2)': 810,
#   '(gm-csf,stat5)': 811,
#   '(estradiol,apoe)': 812,
#   '(lapatinib,erbb)': 813,
#   '(rapamycin,reticulum)': 814,
#   '(dexamethasone,aqp1)': 815,
#   '(mivacurium,butyrylcholinesterase)': 816,
#   '(pazopanib,b-raf)': 817,
#   '(atra,cx43)': 818,
#   '(irap,il-1)': 819,
#   '(furosemide,nkcc1)': 820,
#   '(fibrates,sr-bi)': 821,
#   '(5-asa,sasp)': 822,
#   '(trastuzumab,her2)': 823,
#   '(metyrapone,cyp3a)': 824,
#   '(sucralfate,bfgf)': 825,
#   '(propranolol,ml-1)': 826,
#   '(carbamazepine,eaat3)': 827,
#   '(resveratrol,hif-1alpha)': 828,
#   '(gemcitabine,nf-kappab)': 829,
#   '(tenecteplase,alteplase)': 830,
#   '(hyaluronidase,neuraminidase)': 831,
#   '(staurosporine,timp-1)': 832,
#   '(plerixafor,cxcr4)': 833,
#   '(montelukast,cyp2c8)': 834,
#   '(pge2,rankl)': 835,
#   '(duloxetine,bdnf)': 836,
#   '(quinidine,p-gp)': 837,
#   '(hemin,prpc)': 838,
#   '(nadh,tnox)': 839,
#   '(ampicillin,ml-1)': 840,
#   '(dexamethasone,beta-induced)': 841,
#   '(coxibs,cyclooxygenase-2)': 842,
#   '(gentamicin,phospholipase)': 843,
#   '(curcumin,ap-1)': 844,
#   '(tamoxifen,sr-bi)': 845,
#   '(estradiol,sulfotransferase)': 846,
#   '(efalizumab,etanercept)': 847,
#   '(berberine,nat1)': 848,
#   '(raloxifene,vegf)': 849,
#   '(l-leucine,mtor)': 850,
#   '(triiodothyronine,apob)': 851,
#   '(nevirapine,cyp2b6)': 852,
#   '(doxorubicin,ampk)': 853,
#   '(epirubicin,p-gp)': 854,
#   '(suramin,egfr)': 855,
#   '(metronidazole,cyp3a)': 856,
#   '(fenofibrate,paraoxonase)': 857,
#   '(dexamethasone,mmp-2)': 858,
#   '(dexamethasone,mmp-3)': 859,
#   '(dexamethasone,mmp-9)': 860,
#   '(trimetrexate,dhfr)': 861,
#   '(urokinase,upar)': 862,
#   '(arsenite,hif-1)': 863,
#   '(dexamethasone,pla2)': 864,
#   '(efalizumab,lfa-1)': 865,
#   '(vinblastine,p-gp)': 866,
#   '(rosuvastatin,pcsk9)': 867,
#   '(thyroglobulin,factor-1)': 868,
#   '(creatine,ctnt)': 869,
#   '(nateglinide,pept1)': 870,
#   '(glcnac,mucin)': 871,
#   '(amiodarone,ncx1)': 872,
#   '(bleomycin,blmh)': 873,
#   '(propranolol,5-ht1b)': 874,
#   '(metformin,ampk)': 875,
#   '(propranolol,5-ht1a)': 876,
#   '(isoproterenol,il-1)': 877,
#   '(naloxone,lhrh)': 878,
#   '(aldosterone,osteopontin)': 879,
#   '(lamivudine,ifn-alpha)': 880,
#   '(creatine,ctni)': 881,
#   '(methacholine,copd)': 882,
#   '(gm-csf,jak2)': 883,
#   '(vasopressin,calmodulin)': 884,
#   '(octreotide,stat3)': 885,
#   '(pge2,stat3)': 886,
#   '(arsenite,nqo1)': 887,
#   '(rolipram,il-5)': 888,
#   '(fenofibrate,adiponectin)': 889,
#   '(gp120,lectin)': 890,
#   '(estradiol,hsd17b7)': 891,
#   '(clenbuterol,ml-1)': 892,
#   '(sumatriptan,5-ht1d)': 893,
#   '(acitretin,etanercept)': 894,
#   '(bortezomib,mcl-1)': 895,
#   '(sumatriptan,5-ht1b)': 896,
#   '(sumatriptan,5-ht1a)': 897,
#   '(gefitinib,rad51)': 898,
#   '(atorvastatin,tsp-1)': 899,
#   '(paclitaxel,stat3)': 900,
#   '(dexamethasone,ikappabalpha)': 901,
#   '(adalimumab,tace)': 902,
#   '(il-2,erk2)': 903,
#   '(cyclophosphamide,cyp3a4)': 904,
#   '(noradrenaline,calcitonin)': 905,
#   '(erlotinib,mtor)': 906,
#   '(ouabain,adenosinetriphosphatase)': 907,
#   '(clenbuterol,igf-i)': 908,
#   '(sevoflurane,ho-1)': 909,
#   '(phylloquinone,osteocalcin)': 910,
#   '(sildenafil,pde5a)': 911,
#   '(fenofibrate,tlr4)': 912,
#   '(apap,cyp3a4)': 913,
#   '(cefadroxil,pept2)': 914,
#   '(lansoprazole,bfgf)': 915,
#   '(pge2,cyclooxygenase-2)': 916,
#   '(carboplatin,gm-csf)': 917,
#   '(paclitaxel,egfr)': 918,
#   '(estradiol,bdnf)': 919,
#   '(gemfibrozil,cyp2c8)': 920,
#   '(cisplatin,rad51)': 921,
#   '(simvastatin,sr-bi)': 922,
#   '(dexamethasone,ap-1)': 923,
#   '(simvastatin,vegf)': 924,
#   '(muraglitazar,ppar)': 925,
#   '(melatonin,5-ht2a)': 926,
#   '(tnf-r2,traf2)': 927,
#   '(bortezomib,nf-kappab)': 928,
#   '(danazol,sulfatase)': 929,
#   '(erlotinib,egfr)': 930,
#   '(isoproterenol,creb)': 931,
#   '(d-tubocurarine,nachr)': 932,
#   '(et743,top1)': 933,
#   '(imatinib,egfr)': 934,
#   '(dexamethasone,bfgf)': 935,
#   '(rapamycin,her2)': 936,
#   '(resveratrol,vegf)': 937,
#   '(dexamethasone,cd38)': 938,
#   '(estradiol,beta-endorphin)': 939,
#   '(rolipram,creb)': 940,
#   '(fk506,bdnf)': 941,
#   '(dexamethasone,factor-1)': 942,
#   '(dexamethasone,sp-a)': 943,
#   '(dexamethasone,sp-c)': 944,
#   '(dexamethasone,sp-b)': 945,
#   '(dexamethasone,sp-d)': 946,
#   '(nadh,nicotinamide)': 947,
#   '(saha,hdac)': 948,
#   '(dexamethasone,iapp)': 949,
#   '(sn-38,ugt1a1)': 950,
#   '(genistein,pai-1)': 951,
#   '(diltiazem,ml-1)': 952,
#   '(perhexiline,cyp2d6)': 953,
#   '(bortezomib,caspase-3)': 954,
#   '(adomet,mat1a)': 955,
#   '(pentamidine,rgds)': 956,
#   '(propranolol,nadph)': 957,
#   '(aldosterone,ctgf)': 958,
#   '(lovastatin,p-gp)': 959,
#   '(curcumin,gadd153)': 960,
#   '(resveratrol,adiponectin)': 961,
#   '(ajmaline,herg)': 962,
#   '(curcumin,pla2)': 963,
#   '(imipramine,bdnf)': 964,
#   '(curcumin,mmp-9)': 965,
#   '(curcumin,mmp-2)': 966,
#   '(nelfinavir,cyp3a4)': 967,
#   '(gentamicin,caspase-3)': 968,
#   '(curcumin,mmp-3)': 969,
#   '(selegiline,mao-b)': 970,
#   '(dicoumarol,hsp90)': 971,
#   '(paclitaxel,her-2)': 972,
#   '(oltipraz,cyp2b6)': 973,
#   '(melatonin,gdnf)': 974,
#   '(resveratrol,egr-1)': 975,
#   '(vardenafil,abcb1)': 976,
#   '(aldosterone,inos)': 977,
#   '(cyclophosphamide,filgrastim)': 978,
#   '(selegiline,mao-a)': 979,
#   '(carbachol,gastrin)': 980,
#   '(metformin,resistin)': 981,
#   '(propofol,hif-1)': 982,
#   '(picrotoxin,glyrs)': 983,
#   '(nimesulide,aromatase)': 984,
#   '(il-2,p21ras)': 985,
#   '(digoxin,hif-1alpha)': 986,
#   '(chloroquine,phospholipase)': 987,
#   '(raltegravir,ugt1a1)': 988,
#   '(atra,il-10)': 989,
#   '(miconazole,aromatase)': 990,
#   '(benzbromarone,urat1)': 991,
#   '(albuterol,copd)': 992,
#   '(fk506,fkbp5)': 993,
#   '(budesonide,icam-1)': 994,
#   '(aldosterone,wnk4)': 995,
#   '(diethylcarbamazine,leukotriene)': 996,
#   '(n-acetylcysteine,egfr)': 997,
#   '(amlodipine,egfr)': 998,
#   '(melatonin,12-lox)': 999,
#   '(etodolac,cyclooxygenase-2)': 1000,
#   ...}}

# %% [markdown]
# Now we actually calculate the test set scores for one test set using the `count_scores` function built in the EBCScoring module. This is just summing up all the ranks of the seed set members associated with that particular test set member.

# %%
test_set_scores = e.count_scores(rankings=rankings, ebc_scoring_artifact=scoring)
test_set_scores.keys()

v.bar(x = list(test_set_scores.keys()), y = list(test_set_scores.values()), title = "Sample Ranksum Scores for Size 10 Test Set")
# Out:
# Bar displayed...

# %%
test
# Out:
#                     Drug-Gene  Drug-Gene Cluster  \
# 2567       (ritonavir/cyp2d6)               28.0
# 824        (plerixafor/cxcr4)                1.0
# 2607       (diazepam/cyp2c19)               15.0
# 3339        (warfarin/cyp2c9)               15.0
# 3180   (dexamethasone/cyp1a1)                5.0
# 1686  (estradiol/osteocalcin)               13.0
# 2471         (etoposide/parp)               21.0
# 2238          (imatinib/pc-3)               21.0
# 2504      (flurbiprofen/cgrp)               21.0
# 1943      (formoterol/gm-csf)               28.0
#
#                                      Dependency Path  Dependency path Cluster  \
# 2567                                             NaN                      NaN
# 824   [nsubjpass, administered, prep_to, mice, amod]                      8.0
# 2607                                             NaN                      NaN
# 3339                                             NaN                      NaN
# 3180                                             NaN                      NaN
# 1686                                             NaN                      NaN
# 2471                                             NaN                      NaN
# 2238                                             NaN                      NaN
# 2504                                             NaN                      NaN
# 1943                                             NaN                      NaN
#
#       DrugBank
# 2567      True
# 824       True
# 2607      True
# 3339      True
# 3180      True
# 1686     False
# 2471     False
# 2238     False
# 2504     False
# 1943     False

# %% [markdown]
# # General Application
#
# Now we repeat this process R times and generate R test-seed sets of varying sizes. Seed set size can go from 5 to a high of 12.

# %%
import pandas as pd
from module4.ebc_scoring import EBCScoring


e = EBCScoring()

seed_test_sets, all_test_set_scores = e.run_R_times(low = 10, high = 50, R = 100)

# %%
s,t = seed_test_sets[0]
t.head(10)
# Out:
#                   Drug-Gene  Drug-Gene Cluster Dependency Path  \
# 2394    (flecainide/cyp2d6)               28.0             NaN
# 2511  (theophylline/cyp2e1)                9.0             NaN
# 3386     (gemcitabine/rrm1)               10.0             NaN
# 3220  (aldosterone/cyp11b1)               20.0             NaN
# 1507      (dicoumarol/nqo1)               12.0             NaN
# 1528     (estradiol/ugt1a1)               14.0             NaN
# 2112     (tamoxifen/cyp2d6)               17.0             NaN
# 1305      (thiotepa/cyp2b6)               23.0             NaN
# 2567     (ritonavir/cyp2d6)               28.0             NaN
# 2074      (dantrolene/ryr1)               10.0             NaN
#
#       Dependency path Cluster  DrugBank
# 2394                      NaN      True
# 2511                      NaN      True
# 3386                      NaN      True
# 3220                      NaN      True
# 1507                      NaN      True
# 1528                      NaN      True
# 2112                      NaN      True
# 1305                      NaN      True
# 2567                      NaN      True
# 2074                      NaN      True

# %%
all_test_set_scores[0]
# Out:
# {'(cetuximab,egfr)': 3325,
#  '(mitoxantrone,abcg2)': 3407,
#  '(protamine,tfpi)': 3505,
#  '(urokinase,pai-2)': 3391,
#  '(rapamycin,aicar)': 3507,
#  '(carnitine,crat)': 3474,
#  '(ticagrelor,p2y12)': 3248,
#  '(gm-csf,stat1)': 3377,
#  '(omeprazole,cyp3a4)': 3493,
#  '(amitriptyline,eaat3)': 3466,
#  '(thiotepa,cyp2b6)': 3466,
#  '(dicoumarol,nqo1)': 3507,
#  '(estradiol,ugt1a1)': 3356,
#  '(corticosteroids,adrenocorticotropin)': 3483,
#  '(omeprazole,cyp1a1)': 3509,
#  '(ketamine,hsp70)': 3499,
#  '(pertuzumab,her-2)': 3256,
#  '(dantrolene,ryr1)': 3327,
#  '(dasatinib,epha2)': 3497,
#  '(tamoxifen,cyp2d6)': 3270,
#  '(flutamide,cyp1a2)': 3499,
#  '(menadione,sod1)': 3482,
#  '(hyaluronan,habp1)': 3425,
#  '(capecitabine,her2)': 3461,
#  '(flecainide,cyp2d6)': 3274,
#  '(norepinephrine,phospholipase)': 3508,
#  '(methylprednisolone,il-10)': 3504,
#  '(resveratrol,pkm2)': 3509,
#  '(theophylline,cyp2e1)': 3489,
#  '(ritonavir,cyp2d6)': 3177,
#  '(ezetimibe,statin)': 3453,
#  '(etodolac,il-1)': 3511,
#  '(clozapine,cyp2d6)': 3465,
#  '(naltrexone,oprm1)': 3299,
#  '(gemfibrozil,inos)': 3414,
#  '(voriconazole,cyp2c19)': 3456,
#  '(aldosterone,cyp11b1)': 3505,
#  '(gemcitabine,rrm1)': 3397}

# %%
len(all_test_set_scores)
# Out:
# 100

# %%
import pickle
from datetime import datetime

time = datetime.now().strftime("%Y-%m-%d,%H:%M")

with open("../data/artifacts/scores/test_sets" + f"_{time}.txt", "wb") as fp:   #Pickling
    pickle.dump(all_test_set_scores, fp)

# Saving corresponding seed test sets
with open("../data/artifacts/scores/seed_test_sets" + f"_{time}.txt", "wb") as fp:
    pickle.dump(seed_test_sets, fp)

# %%
with open("/Users/mtaruno/Documents/DevZone/Stem-Away-group-5/data/artifacts/scores/test_sets_2021-08-14,08:29.txt", "rb") as fp:   # Unpickling
    test_sets = pickle.load(fp)

# %%
# Out:
# [{'(dexamethasone,cyp2e1)': 3204,
#   '(lamotrigine,ugt1a4)': 523,
#   '(celecoxib,egfr)': 2645,
#   '(pioglitazone,pai-1)': 2807},
#  {'(sorafenib,braf)': 3261,
#   '(cisplatin,tlr4)': 3241,
#   '(naltrexone,oprm1)': 2123,
#   '(dhea,g6pdh)': 3443},
#  {'(risperidone,cyp2d6)': 2608,
#   '(lamotrigine,ugt1a4)': 2804,
#   '(dapsone,cyp2c9)': 3462,
#   '(curcumin,hsp70)': 3447,
#   '(menadione,nadph)': 3302,
#   '(gm-csf,cd40)': 3447},
#  {'(pge2,inositol)': 3459,
#   '(cilastatin,dehydropeptidase-i)': 2136,
#   '(lapatinib,erbb2)': 2101,
#   '(levodopa,catechol-o-methyltransferase)': 1900,
#   '(lidocaine,egfr)': 3147,
#   '(il-2,rantes)': 3424,
#   '(diazepam,cyp3a4)': 3394,
#   '(vasopressin,avpr1b)': 3468,
#   '(aldosterone,cyp11b2)': 3473,
#   '(indomethacin,endothelin-1)': 3441},
#  {'(cyclophosphamide,cyp2b6)': 3454,
#   '(cisplatin,cd44)': 3480,
#   '(danazol,sulfatase)': 2548,
#   '(diethylcarbamazine,leukotriene)': 3048,
#   '(resveratrol,cyp1a1)': 1382,
#   '(flecainide,cyp2d6)': 2134,
#   '(rolipram,pde4b)': 2595,
#   '(dexamethasone,p300)': 3502},
#  {'(nadh,sir2)': 1844,
#   '(rosiglitazone,cyp2c8)': 3398,
#   '(chlorpromazine,herg)': 3367,
#   '(alfentanil,cyp3a4)': 3445,
#   '(colchicine,cyp3a4)': 1744,
#   '(donepezil,butyrylcholinesterase)': 2030,
#   '(genistein,cyclooxygenase-2)': 3442,
#   '(danazol,shbg)': 3172,
#   '(celecoxib,hoat3)': 1743,
#   '(proguanil,dhfr)': 1857},
#  {'(tamoxifen,survivin)': 2771,
#   '(clopidogrel,cyp3a4)': 2333,
#   '(pge2,bcl-2)': 3093,
#   '(bisphosphonate,hebp)': 3328,
#   '(imatinib,cyp3a4)': 3462,
#   '(camptothecin,top1)': 3497},
#  {'(staurosporine,pkc-zeta)': 3253,
#   '(gm-csf,mcp-1)': 3477,
#   '(theophylline,cyp1a2)': 3180,
#   '(colchicine,cyp3a4)': 3410,
#   '(collagenase,mmp-8)': 3153,
#   '(terfenadine,cyp3a4)': 3253,
#   '(rosiglitazone,pparg)': 3343,
#   '(mivacurium,pseudocholinesterase)': 3354,
#   '(verapamil,mdr1)': 3420,
#   '(cisplatin,atp7b)': 3338},
#  {'(losartan,cyp2c9)': 3474,
#   '(glimepiride,caveolin-1)': 3230,
#   '(troleandomycin,cyp3a4)': 2008,
#   '(voriconazole,cyp3a4)': 1286,
#   '(estradiol,cd40l)': 3294,
#   '(dibucaine,butyrylcholinesterase)': 1408},
#  {'(capsaicin,trpv1)': 3474,
#   '(dicoumarol,nqo1)': 1933,
#   '(doxycycline,mmp-13)': 3241,
#   '(daunorubicin,nfkappab)': 3481},
#  {'(lenograstim,g-csf)': 3394,
#   '(permethrin,nets)': 3458,
#   '(thiotepa,cyp2b6)': 1888,
#   '(resveratrol,cyp1a1)': 2624,
#   '(aprepitant,cyp3a4)': 1677,
#   '(paclitaxel,ap-1)': 3217,
#   '(docetaxel,cyp3a4)': 3192,
#   '(rosiglitazone,adiponectin)': 3288,
#   '(orlistat,cyp3a4)': 3489,
#   '(dexamethasone,pthrp)': 3510},
#  {'(succinyldicholine,cholinesterase)': 2595,
#   '(efalizumab,lfa-1)': 1990,
#   '(omeprazole,cyp3a4)': 3209,
#   '(gemfibrozil,pai-1)': 3288,
#   '(sparteine,cyp2d6)': 3097,
#   '(maraviroc,cyp3a4)': 2828,
#   '(atra,rar-alpha)': 3462,
#   '(diazepam,cyp2c19)': 2917,
#   '(flurbiprofen,cyp2c9)': 3097,
#   '(doxycycline,vegf)': 3398},
#  {'(estradiol,shbg)': 3352,
#   '(berberine,nat1)': 3338,
#   '(trastuzumab,erbb2)': 2802,
#   '(celecoxib,bcl-2)': 3334,
#   '(ritonavir,cyp3a4)': 2313,
#   '(atra,evi-1)': 3477},
#  {'(lovastatin,cyp3a4)': 1288,
#   '(fentanyl,cyp3a4)': 3214,
#   '(levonorgestrel,shbg)': 2520,
#   '(flavopiridol,cdk2)': 1202,
#   '(isoproterenol,beta2ar)': 3192,
#   '(bezafibrate,ppar-alpha)': 3134},
#  {'(neostigmine,cholinesterase)': 1088,
#   '(resveratrol,survivin)': 3402,
#   '(pge2,cyclooxygenase-2)': 3312,
#   '(melatonin,cyp1a2)': 2428,
#   '(pilocarpine,cyp2a6)': 1295,
#   '(flurbiprofen,cyp2c9)': 3038},
#  {'(pertuzumab,erbb2)': 3417,
#   '(collagenase,timp)': 2935,
#   '(thyroxine,calcitonin)': 3180,
#   '(levodopa,mao-b)': 3159,
#   '(carvedilol,herg)': 3182,
#   '(alemtuzumab,cd52)': 3399,
#   '(amodiaquine,cyp2c8)': 3113,
#   '(tamoxifen,cyp3a4)': 3385,
#   '(propofol,beta2)': 3187,
#   '(probucol,abca1)': 3230},
#  {'(lovastatin,pten)': 3177,
#   '(danazol,sulfatase)': 3186,
#   '(gefitinib,abcg2)': 3453,
#   '(dexamethasone,15-pgdh)': 3289,
#   '(cyclosporine,cyp3a4)': 1930,
#   '(terfenadine,cyp3a4)': 3253,
#   '(torcetrapib,cetp)': 2160,
#   '(forskolin,pai-1)': 3177,
#   '(aprepitant,nk-1)': 2492,
#   '(propafenone,cyp1a2)': 3103},
#  {'(norepinephrine,gnrh)': 3413,
#   '(losartan,cyp2c9)': 3438,
#   '(nevirapine,cyp2b6)': 3486,
#   '(atorvastatin,ldlc)': 3506,
#   '(voriconazole,cyp2c9)': 2257,
#   '(tamoxifen,maspin)': 3513},
#  {'(fluvastatin,nf-kappab)': 3273,
#   '(delavirdine,cyp3a4)': 1942,
#   '(miconazole,aromatase)': 2195,
#   '(repaglinide,cyp2c8)': 2921,
#   '(gefitinib,egfr)': 2875,
#   '(troleandomycin,cyp3a4)': 1960,
#   '(celecoxib,ho-1)': 3236,
#   '(simvastatin,slco1b1)': 3474,
#   '(estradiol,stat3)': 3381,
#   '(pimozide,calmodulin)': 2782},
#  {'(lovastatin,cyp3a4)': 1364,
#   '(papaverine,pde10a)': 1746,
#   '(diclofenac,cyp2c9)': 3445,
#   '(norepinephrine,cort)': 3471,
#   '(calcitriol,cyp24a1)': 3496,
#   '(gp120,icam-1)': 3467,
#   '(ara-c,g-csf)': 3395,
#   '(lovastatin,rhoa)': 3490,
#   '(tamoxifen,cyp3a4)': 3460,
#   '(phenothiazine,calmodulin)': 2406},
#  {'(atra,gm-csf)': 3280,
#   '(mexiletine,lqt3)': 3379,
#   '(nilotinib,pdgfr)': 1863,
#   '(forskolin,proenkephalin)': 3356,
#   '(ciprofloxacin,cyp1a2)': 1394,
#   '(flecainide,cyp2d6)': 1480,
#   '(olanzapine,cyp1a2)': 2910,
#   '(aripiprazole,drd2)': 3505,
#   '(simvastatin,slco1b1)': 3446,
#   '(pge2,gastrin)': 3358},
#  {'(zuclopenthixol,cyp2d6)': 2898,
#   '(norepinephrine,cort)': 3511,
#   '(rosiglitazone,cyp2c8)': 3369,
#   '(atorvastatin,nf-kappab)': 2232,
#   '(everolimus,mtor)': 2337,
#   '(terfenadine,cyp3a4)': 3213,
#   '(il-2,il-10)': 3219,
#   '(sulfasalazine,nat2)': 3491},
#  {'(genistein,icam-1)': 3472,
#   '(nevirapine,cyp2b6)': 3261,
#   '(glutaraldehyde,srbc)': 3495,
#   '(clopidogrel,cyp3a4)': 3442,
#   '(g-csf,vegf)': 3498,
#   '(atra,evi-1)': 3471,
#   '(aminopterin,dhfr)': 3332,
#   '(tolterodine,cyp2d6)': 3260,
#   '(acarbose,alpha-glucosidase)': 3465,
#   '(methoxsalen,cyp2a6)': 3364},
#  {'(omeprazole,cyp2c19)': 765,
#   '(vigabatrin,swds)': 3192,
#   '(sitagliptin,dpp4)': 1440,
#   '(vasopressin,endothelin-1)': 3484},
#  {'(fluorescein,cd45)': 3328,
#   '(maraviroc,cyp3a4)': 2568,
#   '(alemtuzumab,cd52)': 2825,
#   '(thyroglobulin,calcitonin)': 3460},
#  {'(suramin,vegf)': 3473,
#   '(mexiletine,cyp2d6)': 3365,
#   '(fluconazole,cyp2c9)': 2344,
#   '(pge2,survivin)': 3333,
#   '(hydroxyurea,ifn-alpha)': 3395,
#   '(atazanavir,ugt1a1)': 2055,
#   '(sorafenib,braf)': 2348,
#   '(fluvastatin,statin)': 3404,
#   '(buspirone,cyp3a4)': 3462,
#   '(tetrabenazine,vmat2)': 2379},
#  {'(cysteamine,gastrin)': 3420,
#   '(geldanamycin,hsp70)': 3317,
#   '(phenytoin,cyp2c19)': 3286,
#   '(haloperidol,cyp3a4)': 2556,
#   '(gemfibrozil,pai-1)': 3500,
#   '(triazolam,cyp3a4)': 3332,
#   '(orphenadrine,cyp2b6)': 2995,
#   '(octreotide,ho-1)': 3492,
#   '(flecainide,cyp2d6)': 3060,
#   '(doxycycline,vegf)': 3435},
#  {'(il-2,nf-kappab)': 3471,
#   '(paclitaxel,nfkappab)': 3216,
#   '(isoflurane,lfa-1)': 3412,
#   '(clozapine,cyp1a2)': 2414,
#   '(trastuzumab,erbb2)': 1574,
#   '(atorvastatin,abcb1)': 3333,
#   '(eletriptan,cyp3a4)': 3427,
#   '(aminopterin,dhfr)': 1416,
#   '(physostigmine,cholinesterase)': 1227,
#   '(cisplatin,tace)': 1058},
#  {'(tramadol,cyp2d6)': 3340,
#   '(clozapine,cyp1a2)': 3371,
#   '(benzbromarone,cyp2c9)': 3179,
#   '(spermine,irk1)': 3491,
#   '(pgi2,ptgis)': 3285,
#   '(neratinib,abcb1)': 3323,
#   '(evodiamine,nf-kappab)': 3383,
#   '(hyaluronan,has1)': 3262,
#   '(cisplatin,atp7b)': 3338,
#   '(rapamycin,rictor)': 3165},
#  {'(montelukast,cyp2c8)': 1974,
#   '(trimetrexate,dhfr)': 2343,
#   '(resveratrol,egr-1)': 3304,
#   '(quinacrine,il-1)': 3334,
#   '(neomycin,phospholipase)': 2133,
#   '(timolol,cyp2d6)': 2875,
#   '(tamoxifen,cyp3a4)': 3327,
#   '(isoproterenol,mcp-1)': 3494,
#   '(gemcitabine,survivin)': 3353,
#   '(voriconazole,cyp2c19)': 3382},
#  {'(bupropion,cyp2d6)': 2196,
#   '(sunitinib,abcg2)': 2702,
#   '(losartan,cyp2c9)': 3135,
#   '(diclofenac,ugt2b7)': 1950,
#   '(fluconazole,ugt2b7)': 1593,
#   '(acarbose,maltase-glucoamylase)': 2561,
#   '(isoniazid,cyp2e1)': 3213,
#   '(il-2,jak1)': 3242,
#   '(genistein,igf-i)': 3247,
#   '(mk-571,mrp1)': 2608},
#  {'(fluconazole,cyp3a4)': 2117,
#   '(pravastatin,mcp-1)': 3388,
#   '(oxaliplatin,survivin)': 1822,
#   '(fluvoxamine,cyp1a2)': 2198},
#  {'(estradiol,cyp3a4)': 3130,
#   '(permethrin,nets)': 3122,
#   '(genistein,bfgf)': 3003,
#   '(resveratrol,cyp1a1)': 2208,
#   '(imatinib,cyp3a4)': 2235,
#   '(mitoxantrone,bcrp)': 2199},
#  {'(zuclopenthixol,cyp2d6)': 3252,
#   '(sorafenib,p-gp)': 3246,
#   '(diclofenac,ho-1)': 3377,
#   '(il-11,survivin)': 3476,
#   '(estradiol,ugt1a1)': 3485,
#   '(orphenadrine,cyp2b6)': 3368,
#   '(troglitazone,ampk)': 3411,
#   '(verapamil,abcb1)': 3409,
#   '(dexamethasone,bcl-x)': 3480,
#   '(pranlukast,cyp3a4)': 2184},
#  {'(pge2,il-23)': 3388,
#   '(imipramine,cyp2c19)': 3374,
#   '(trimethoprim,nadph)': 1917,
#   '(ara-c,ifn-alpha)': 3358,
#   '(voriconazole,cyp3a4)': 626,
#   '(midazolam,cyp3a4)': 2619},
#  {'(risperidone,cyp2d6)': 3127,
#   '(erlotinib,egfr)': 3283,
#   '(propofol,icam-1)': 3339,
#   '(entacapone,catechol-o-methyltransferase)': 3139},
#  {'(il-2,nf-kappab)': 3359,
#   '(tacrolimus,cyp3a4)': 3407,
#   '(ornithine,inos)': 2015,
#   '(lubiprostone,clc-2)': 3487,
#   '(naloxone,tlr4)': 3216,
#   '(rabeprazole,cyp2c19)': 3030,
#   '(cisplatin,foxo3a)': 2150,
#   '(amitriptyline,cyp2d6)': 3260,
#   '(curcumin,sult1a1)': 2992,
#   '(paclitaxel,cyp2c8)': 3375},
#  {'(spermine,ssat)': 3158,
#   '(clopidogrel,cyp2c19)': 1210,
#   '(paclitaxel,cox-2)': 3122,
#   '(naloxone,lhrh)': 3102,
#   '(fluconazole,cyp2c9)': 1944,
#   '(triazolam,cyp3a4)': 3171,
#   '(pilocarpine,cyp2a6)': 1948,
#   '(daunorubicin,mdr1)': 3245,
#   '(rizatriptan,cgrp)': 3135,
#   '(rofecoxib,cyp1a2)': 1597},
#  {'(pazopanib,vegf)': 3506,
#   '(sorafenib,flt3)': 3226,
#   '(nitroprusside,edrf)': 3172,
#   '(docetaxel,cyp1b1)': 2706,
#   '(telithromycin,cyp3a4)': 3107,
#   '(carvedilol,herg)': 2889},
#  {'(lansoprazole,cyp2c19)': 449,
#   '(dhea,il-10)': 2737,
#   '(etoposide,cyp3a4)': 347,
#   '(pyridoxal,palp)': 2497},
#  {'(melatonin,12-lox)': 3211,
#   '(ziprasidone,cyp3a4)': 2589,
#   '(il-1ra,il-1)': 3433,
#   '(propranolol,cyp2d6)': 2372},
#  {'(dhea,g6pase)': 2994,
#   '(estradiol,ugt1a1)': 821,
#   '(imatinib,cyp3a4)': 1156,
#   '(gm-csf,cd34)': 2865},
#  {'(imatinib,hoct1)': 2923,
#   '(loratadine,cyp2d6)': 3266,
#   '(dhea,g6pd)': 2359,
#   '(atorvastatin,abcb1)': 3382,
#   '(flavopiridol,cdk2)': 1968,
#   '(dantrolene,ryr1)': 2734,
#   '(paclitaxel,nf-kappab)': 3353,
#   '(resveratrol,sirt1)': 3406},
#  {'(estradiol,ugt1a1)': 3084,
#   '(nifedipine,nf-kappab)': 3334,
#   '(aldosterone,aqp2)': 3455,
#   '(estradiol,comt)': 3090,
#   '(trastuzumab,p27kip1)': 3348,
#   '(diazepam,cyp2c19)': 3144,
#   '(fk506,cd40l)': 3440,
#   '(ketoconazole,cyp3a4)': 3014},
#  {'(geldanamycin,hsp70)': 3077,
#   '(gefitinib,cyp3a4)': 1509,
#   '(quinidine,cyp2d6)': 2389,
#   '(tacrine,cyp1a2)': 2815,
#   '(tamoxifen,ki-67)': 3119,
#   '(atomoxetine,cyp2d6)': 2926,
#   '(collagenase,mmp-2)': 2040,
#   '(risperidone,5-ht2a)': 2860},
#  {'(naringenin,tslp)': 3502,
#   '(diazepam,egr-1)': 3336,
#   '(disulfiram,aldh2)': 2564,
#   '(succinylcholine,bche)': 3247,
#   '(tacrolimus,cyp3a5)': 3503,
#   '(temsirolimus,vegf)': 3424,
#   '(cerivastatin,cyp2c8)': 3359,
#   '(dicoumarol,dt-diaphorase)': 3019},
#  {'(leuprolide,gnrh)': 3482,
#   '(mianserin,5-ht2a)': 3282,
#   '(topotecan,abcg2)': 3404,
#   '(clarithromycin,cyp3a4)': 1005},
#  {'(propofol,ugt1a9)': 2064,
#   '(il-2,iddm)': 3338,
#   '(ketanserin,5-ht-2)': 2846,
#   '(tamoxifen,cyp2d6)': 2978,
#   '(hyaluronan,habp1)': 2482,
#   '(pyrazinamide,nicotinamide)': 3399,
#   '(tamoxifen,cyp3a4)': 3424,
#   '(propofol,beta2)': 3462,
#   '(dexamethasone,cyp1a1)': 3395,
#   '(cisplatin,atp7b)': 3417},
#  {'(pertuzumab,erbb2)': 1933,
#   '(tofisopam,cyp3a4)': 2963,
#   '(cilostazol,cd62p)': 3246,
#   '(norepinephrine,endothelin-1)': 3231,
#   '(cyclosporin,p-gp)': 1036,
#   '(clomipramine,cyp2d6)': 2482,
#   '(voriconazole,cyp2c9)': 1409,
#   '(il-2,il-18)': 3334,
#   '(dexamethasone,p450scc)': 3292,
#   '(gemcitabine,rrm1)': 2785},
#  {'(dextromethorphan,cyp2c9)': 3435,
#   '(pge2,il-1ra)': 3427,
#   '(indomethacin,akr1c3)': 2990,
#   '(gm-csf,sargramostim)': 3344,
#   '(orphenadrine,cyp2b6)': 1965,
#   '(nadh,gapdh)': 3418,
#   '(curcumin,cftr)': 3363,
#   '(dexamethasone,inositol)': 3341},
#  {'(phenprocoumon,cyp2c9)': 2507,
#   '(delavirdine,cyp3a4)': 1367,
#   '(sildenafil,pde5a)': 1269,
#   '(atra,irf-1)': 3293,
#   '(pilocarpine,cyp2a6)': 1094,
#   '(pioglitazone,lox-1)': 3320,
#   '(ndga,5-lipoxygenase)': 1268,
#   '(montelukast,cyslt1)': 1481},
#  {'(clozapine,cyp1a2)': 809,
#   '(isoprenaline,cgrp)': 3033,
#   '(chloramphenicol,pomc)': 3040,
#   '(tacrine,cyp1a2)': 2701,
#   '(corticosteroids,vegf)': 3208,
#   '(gemfibrozil,ppar)': 3425,
#   '(ritonavir,cyp3a4)': 1911,
#   '(mexiletine,cyp1a2)': 1100},
#  {'(clozapine,cyp1a2)': 3302,
#   '(nadh,nicotinamide)': 3385,
#   '(omeprazole,cyp3a4)': 3330,
#   '(corticosteroids,vegf)': 3485,
#   '(aminopterin,dhfr)': 2280,
#   '(rapamycin,rapa)': 3297,
#   '(staurosporine,cdk2)': 2051,
#   '(erythromycin,p-gp)': 3453},
#  {'(glyburide,cyp2c9)': 3293,
#   '(cisplatin,ho-1)': 3307,
#   '(prostacyclin,calcitonin)': 3328,
#   '(gefitinib,abcg2)': 3334,
#   '(nadh,ndh2)': 3483,
#   '(tamoxifen,cyp2c9)': 1320,
#   '(digoxin,abcb1)': 3155,
#   '(dhea,gnrh)': 3293},
#  {'(sunitinib,abcg2)': 2082,
#   '(pge2,mcp-1)': 3441,
#   '(sildenafil,vegf)': 3398,
#   '(forskolin,phospholipase)': 3215,
#   '(resveratrol,sirt1)': 3432,
#   '(carbamazepine,cyp3a4)': 3297},
#  {'(sunitinib,abcg2)': 989,
#   '(tcgf,lymphokine)': 3387,
#   '(triiodothyronine,shbg)': 3427,
#   '(clozapine,cyp1a2)': 1213,
#   '(atorvastatin,vegf)': 3499,
#   '(escitalopram,cyp2d6)': 2067,
#   '(vincristine,hsp27)': 3482,
#   '(rituximab,fcgr3a)': 3416,
#   '(aldosterone,cyp11b2)': 3392,
#   '(creatine,gamt)': 3276},
#  {'(moclobemide,cyp2c19)': 3351,
#   '(clenbuterol,ml-1)': 3505,
#   '(minocycline,mmp-9)': 3511,
#   '(felodipine,cyp3a4)': 2788,
#   '(oxytocin,oxtr)': 3470,
#   '(staurosporine,gnrh)': 3425,
#   '(lidoflazine,herg)': 3487,
#   '(celecoxib,cyp2c9)': 3328},
#  {'(diltiazem,ml-1)': 3423,
#   '(colchicine,cyp3a4)': 2682,
#   '(thioridazine,cyp2d6)': 1295,
#   '(ritonavir,cyp3a4)': 1974,
#   '(mibefradil,cyp3a4)': 1919,
#   '(diclofenac,cox-2)': 2363,
#   '(nateglinide,glp-1)': 3365,
#   '(sn-38,ugt1a)': 3134},
#  {'(gefitinib,abcg2)': 3313,
#   '(cisplatin,mad2)': 2487,
#   '(capsaicin,cgrp)': 2670,
#   '(norepinephrine,lhrh)': 2647,
#   '(dexamethasone,cyp1a1)': 2640,
#   '(proguanil,dhfr)': 2904},
#  {'(rituximab,bcl-2)': 3465,
#   '(coumarin,cyp2a6)': 3334,
#   '(dexamethasone,ppar-gamma)': 3378,
#   '(fenofibrate,statin)': 3336,
#   '(tacrolimus,cyp3a4)': 3467,
#   '(fexofenadine,p-gp)': 3491,
#   '(atazanavir,ugt1a1)': 1595,
#   '(genistein,cyp1a1)': 3309},
#  {'(captopril,kallikrein)': 3490,
#   '(piperazine,5-ht1a)': 3462,
#   '(levetiracetam,sv2a)': 2974,
#   '(oxytocin,oxtr)': 3445,
#   '(pge2,cgrp)': 3350,
#   '(estradiol,cyp1b1)': 3300},
#  {'(simvastatin,rhoa)': 2434,
#   '(cyclophosphamide,cyp3a4)': 3379,
#   '(etodolac,cyclooxygenase-2)': 1950,
#   '(lopinavir,cyp3a4)': 3502,
#   '(rapamycin,torc2)': 2086,
#   '(il-2,hdac1)': 3412,
#   '(cimetidine,cyp2d6)': 1629,
#   '(camptothecin,top1)': 1464},
#  {'(prasugrel,cyp2b6)': 1270,
#   '(montelukast,cyp2c8)': 1250,
#   '(gemfibrozil,cyp2c8)': 1404,
#   '(il-11,survivin)': 3485,
#   '(carrageenan,cox-2)': 3389,
#   '(estradiol,sf-1)': 3479},
#  {'(atra,vegf)': 3298,
#   '(sildenafil,abcb1)': 2342,
#   '(cerulenin,fasn)': 2185,
#   '(urokinase,uparap)': 2890,
#   '(aripiprazole,drd2)': 3429,
#   '(dobutamine,ctni)': 2470},
#  {'(melatonin,gnrh)': 3429,
#   '(modafinil,orexin)': 3500,
#   '(cisplatin,caspase-3)': 3441,
#   '(capsaicin,trpv1)': 3485,
#   '(desvenlafaxine,cyp2d6)': 1264,
#   '(lapatinib,erbb2)': 1833,
#   '(pranlukast,cyp3a4)': 1636,
#   '(ndga,15-lox)': 1755},
#  {'(propafenone,cyp2d6)': 3334,
#   '(phenylephrine,egfr)': 3412,
#   '(bevacizumab,vegf-a)': 2744,
#   '(doxorubicin,top2a)': 2704,
#   '(dantrolene,ryr1)': 3078,
#   '(pyrazinamide,nicotinamide)': 3367,
#   '(tamoxifen,cyp3a4)': 3430,
#   '(zolmitriptan,5-ht1b)': 3423},
#  {'(sulindac,survivin)': 3222,
#   '(doxepin,cyp2d6)': 2739,
#   '(itraconazole,cyp3a4)': 911,
#   '(hydrocortisone,gm-csf)': 3120,
#   '(chlorpromazine,pla2)': 889,
#   '(flecainide,cyp2d6)': 1168},
#  {'(scopolamine,scop)': 3330,
#   '(hyaluronan,hyal2)': 3288,
#   '(succinylcholine,bche)': 3412,
#   '(theophylline,cyp1a2)': 2731,
#   '(quinidine,cyp3a4)': 2027,
#   '(dobutamine,mcp-1)': 3490,
#   '(naloxone,tlr4)': 3303,
#   '(hemin,cyp1a1)': 3196},
#  {'(rituximab,bcl-2)': 3416,
#   '(haloperidol,cyp3a4)': 2065,
#   '(glyburide,abca1)': 2303,
#   '(perhexiline,cyp2d6)': 3267,
#   '(flavopiridol,cdk2)': 2143,
#   '(ketanserin,5-ht-2)': 2565,
#   '(quinidine,cyp2d)': 1729,
#   '(nortriptyline,cyp2d6)': 3487,
#   '(sertraline,cyp2d6)': 2203,
#   '(leflunomide,inos)': 3466},
#  {'(metoprolol,copd)': 3476,
#   '(sevoflurane,caspase-3)': 3468,
#   '(orlistat,fasn)': 1655,
#   '(etoposide,cyp3a4)': 3448,
#   '(valspodar,p-gp)': 1725,
#   '(ketamine,bdnf)': 3278,
#   '(aminopterin,dhfr)': 1439,
#   '(artemisinin,cyp2b6)': 3378,
#   '(rofecoxib,cyclooxygenase-2)': 1663,
#   '(warfarin,cyp2c9)': 3438},
#  {'(rapamycin,pten)': 3279,
#   '(hyaluronan,habp)': 2590,
#   '(resveratrol,egr-1)': 3469,
#   '(vardenafil,abcb1)': 3512,
#   '(gm-csf,bcl-2)': 3491,
#   '(vinblastine,cyp3a4)': 3503,
#   '(verapamil,abcb1)': 2562,
#   '(isoflurane,bace)': 2089,
#   '(imiquimod,tlr7)': 3493,
#   '(aldosterone,cyp11b1)': 3514},
#  {'(diphenhydramine,cyp2d6)': 1299,
#   '(il-2,cd132)': 3346,
#   '(bambuterol,bche)': 1324,
#   '(perhexiline,cyp2d6)': 3358,
#   '(docetaxel,cyp1b1)': 3358,
#   '(minocycline,mmp-2)': 3159,
#   '(gp120,dc-sign)': 3481,
#   '(clomipramine,cyp2d6)': 1239,
#   '(hyaluronan,layilin)': 3418,
#   '(pge2,beta-induced)': 3399},
#  {'(dextromethorphan,cyp2c9)': 3354,
#   '(estrone,udp-glucuronosyltransferase)': 3482,
#   '(urokinase,upar)': 3496,
#   '(raltegravir,ugt1a1)': 3267,
#   '(il-2,vegf)': 3459,
#   '(verapamil,cyp3a4)': 1698,
#   '(berberine,adiponectin)': 3506,
#   '(simvastatin,klf2)': 3462,
#   '(vasopressin,avpr1a)': 3404,
#   '(gemcitabine,rrm1)': 2629},
#  {'(forskolin,raf-1)': 1066,
#   '(melatonin,igf-i)': 3445,
#   '(neratinib,abcb1)': 3365,
#   '(ketoconazole,cyp3a4)': 1352},
#  {'(pgi2,pgd2)': 3200,
#   '(il-2,cd23)': 3459,
#   '(disulfiram,aldh2)': 1728,
#   '(nimesulide,cyclooxygenase-2)': 2164,
#   '(pyrimethamine,dhfr)': 2023,
#   '(hesperetin,herg)': 3483,
#   '(resveratrol,cyp3a4)': 2982,
#   '(trimethoprim,cyp2c8)': 1745},
#  {'(nateglinide,cyp2c9)': 2893,
#   '(leuprolide,lhrh)': 3419,
#   '(2-methoxyestradiol,comt)': 2282,
#   '(dutasteride,pca3)': 3382,
#   '(enoxacin,cyp1a2)': 1900,
#   '(delavirdine,cyp3a)': 1532},
#  {'(glyburide,cyp2c9)': 2018,
#   '(cisapride,cyp3a4)': 2913,
#   '(estrone,shbg)': 2644,
#   '(losartan,ctgf)': 2541,
#   '(lovastatin,inos)': 2874,
#   '(dexamethasone,p450scc)': 2722},
#  {'(melatonin,gnrh)': 3473,
#   '(phenprocoumon,cyp2c9)': 2904,
#   '(cimetidine,cyp1a2)': 2484,
#   '(glcnac,mucin)': 3381,
#   '(levodopa,catechol-o-methyltransferase)': 1898,
#   '(calcitriol,cox-2)': 3262,
#   '(resveratrol,cyp3a4)': 2167,
#   '(imiquimod,tlr7)': 3451},
#  {'(propranolol,beta2)': 3298,
#   '(resveratrol,atf3)': 3452,
#   '(duloxetine,cyp2d6)': 2305,
#   '(doxycycline,mmp-13)': 3002,
#   '(2-methoxyestradiol,comt)': 3211,
#   '(erythromycin,cyp3a4)': 2113,
#   '(il-2,fasl)': 3509,
#   '(resveratrol,sirt1)': 3496,
#   '(desipramine,cyp2d6)': 3305,
#   '(dexamethasone,cox-2)': 3498},
#  {'(moclobemide,cyp2c19)': 3503,
#   '(estradiol,beta-galactosidase)': 3281,
#   '(cyclosporin,cyclophilin)': 3462,
#   '(ketoconazole,cyp3a4)': 3466,
#   '(dexamethasone,igfbp-4)': 3274,
#   '(vincristine,cyp3a5)': 3262},
#  {'(alfentanil,cyp3a5)': 2951,
#   '(trastuzumab,erbb2)': 3087,
#   '(forskolin,cox-2)': 3365,
#   '(everolimus,mtor)': 3177,
#   '(curcumin,tlr2)': 2863,
#   '(amodiaquine,cyp2c8)': 3326,
#   '(piroxicam,cox-2)': 2650,
#   '(zidovudine,ifn-alpha)': 3325},
#  {'(il-11,il-10)': 3388,
#   '(progestogens,gnrh)': 3502,
#   '(risperidone,cyp3a4)': 3456,
#   '(rosiglitazone,cyp3a4)': 3492,
#   '(vardenafil,abcb1)': 3496,
#   '(cisplatin,octn2)': 3256,
#   '(rapamycin,cd40)': 3484,
#   '(celecoxib,cox2)': 2699,
#   '(estradiol,comt)': 3498,
#   '(voriconazole,cyp2c9)': 1943},
#  {'(sorafenib,ugt1a1)': 937,
#   '(mianserin,5-ht2c)': 2856,
#   '(anxiolytics,5-ht1a)': 3389,
#   '(nifedipine,cyp3a4)': 2796,
#   '(topotecan,abcg2)': 3124,
#   '(paclitaxel,ikappabalpha)': 3388},
#  {'(haloperidol,cyp2d6)': 1253,
#   '(sunitinib,abcb1)': 3390,
#   '(glyburide,abca1)': 2312,
#   '(tamoxifen,cox-2)': 3289,
#   '(isoniazid,cyp2e1)': 3102,
#   '(fulvestrant,aromatase)': 2489,
#   '(methimazole,fmo1)': 3497,
#   '(verapamil,p-gp)': 2063},
#  {'(mitoxantrone,abcg2)': 1638,
#   '(cisplatin,abcc2)': 3082,
#   '(ketanserin,5-ht2a)': 2573,
#   '(hyaluronidase,hyal2)': 993,
#   '(celecoxib,cyp2c9)': 2450,
#   '(gp120,scd4)': 2041,
#   '(voriconazole,cyp2c19)': 2631,
#   '(doxorubicin,mdr1)': 2330},
#  {'(resveratrol,cyp1a1)': 3039,
#   '(amitriptyline,cyp2d6)': 2993,
#   '(fenoterol,copd)': 3509,
#   '(primaquine,methemoglobin)': 2010,
#   '(sunitinib,vegf)': 3146,
#   '(digoxin,abcb1)': 3155},
#  {'(dextromethorphan,cyp2c9)': 3442,
#   '(risperidone,cyp3a4)': 3398,
#   '(pentamidine,rgds)': 3493,
#   '(tacrine,cyp1a2)': 3296,
#   '(salbutamol,ifn-gamma)': 3384,
#   '(melatonin,sirt1)': 3046},
#  {'(chlorzoxazone,cyp2e1)': 2673,
#   '(aripiprazole,drd2)': 3335,
#   '(indomethacin,il-11)': 3272,
#   '(trastuzumab,kip1)': 3230},
#  {'(mitoxantrone,abcg2)': 2733,
#   '(selegiline,cyp2b6)': 2555,
#   '(indomethacin,il-1)': 3173,
#   '(isoniazid,inha)': 1575,
#   '(genistein,nkcc1)': 2905,
#   '(nutlin-3,rita)': 2672},
#  {'(losartan,mmp-2)': 3476,
#   '(carnitine,acyltransferase)': 2755,
#   '(propofol,hif-1)': 3257,
#   '(erlotinib,cyp3a4)': 2286,
#   '(simvastatin,cyp3a4)': 3103,
#   '(atorvastatin,ampk)': 3493,
#   '(desipramine,cyp2d6)': 2896,
#   '(cisplatin,atp7b)': 3223},
#  {'(efalizumab,cd11a)': 3363,
#   '(dextromethorphan,cyp2c9)': 2619,
#   '(coumarin,cyp2a6)': 3394,
#   '(artemisinin,cdk2)': 2781,
#   '(erlotinib,egfr)': 3104,
#   '(venlafaxine,cyp2d6)': 3310,
#   '(indomethacin,leukotriene)': 3433,
#   '(hemin,cyp1a1)': 2278},
#  {'(dexamethasone,pepck)': 3343,
#   '(cisplatin,hsp27)': 3298,
#   '(neratinib,abcb1)': 3441,
#   '(duloxetine,cyp1a2)': 803},
#  {'(sunitinib,abcb1)': 3247,
#   '(genistein,sulfotransferase)': 3300,
#   '(l-leucine,mtor)': 3193,
#   '(docetaxel,cyp3a4)': 3016,
#   '(aldosterone,phospholipase)': 3502,
#   '(ouabain,phospholipase)': 3390,
#   '(dexamethasone,cyp1a1)': 3389,
#   '(aldosterone,cyp11b1)': 3430},
#  {'(oxycodone,cyp2d6)': 2637,
#   '(curcumin,ap-1)': 1435,
#   '(albendazole,cyp3a4)': 2114,
#   '(isoprenaline,endothelin-1)': 2997},
#  {'(atorvastatin,oatp1b1)': 2715,
#   '(riluzole,cyp1a2)': 2950,
#   '(bortezomib,noxa)': 3328,
#   '(imipramine,cyp2d6)': 2200,
#   '(melatonin,cyp1a2)': 2443,
#   '(vinorelbine,g-csf)': 3442,
#   '(atra,dhand)': 3321,
#   '(docetaxel,cyp3a4)': 3134,
#   '(genistein,nkcc1)': 3301,
#   '(amiodarone,cyp2d6)': 1430},
#  {'(indomethacin,abcc1)': 3444,
#   '(paclitaxel,cox-2)': 3477,
#   '(cyclosporine,hnf4alpha)': 3488,
#   '(curcumin,mmp-9)': 3444,
#   '(estradiol,ugt1a1)': 3377,
#   '(atorvastatin,abcb1)': 3463,
#   '(verapamil,phospholipase)': 3280,
#   '(mephenytoin,cyp2c19)': 3334,
#   '(everolimus,cyp3a4)': 3252,
#   '(rituximab,cd20)': 2903},
#  {'(rapamycin,her2)': 3455,
#   '(clopidogrel,cyp3a4)': 3221,
#   '(captopril,kininogen)': 2685,
#   '(metronidazole,cyp3a4)': 1096},
#  {'(risperidone,cyp2d6)': 3291,
#   '(nateglinide,cyp2c9)': 3365,
#   '(cyclosporine,lymphokine)': 2733,
#   '(rapamycin,pai-1)': 3483,
#   '(sunitinib,flt3)': 3112,
#   '(il-2,vegf)': 3214,
#   '(everolimus,cyp3a4)': 3365,
#   '(pyridoxine,egot)': 2796},
#  {'(elacridar,p-gp)': 3162,
#   '(celecoxib,tcf-1)': 3316,
#   '(fluvastatin,cyp2c9)': 3067,
#   '(atra,igfbp-3)': 3503,
#   '(glimepiride,caveolin-1)': 3405,
#   '(chloroquine,tlr9)': 2069,
#   '(2-methoxyestradiol,comt)': 3049,
#   '(estradiol,comt)': 3478},
#  {'(itraconazole,cyp3a4)': 1815,
#   '(vildagliptin,dpp4)': 2336,
#   '(dexamethasone,osteocalcin)': 1796,
#   '(doxycycline,gdnf)': 3209}]
