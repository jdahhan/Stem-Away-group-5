# %%
import numpy as np
from ebc import EBC 
from matrix import SparseMatrix

with open("resources/matrix-ebc-paper-dense.tsv", "r") as f:
    data = []
    for line in f:
        sl = line.split("\t")
        if len(sl) < 5:  # headers
            continue
        data.append([sl[0], sl[2], float(sl[4])])


n = 3514      # unique drug-gene pairs
m = 1232      # unique dependency paths
matrix = SparseMatrix([n, m]) 
matrix.read_data(data)
matrix.normalize()


Con_mat = np.zeros((n, n), dtype=int) 
for k in range(1000):
    ebc = EBC(matrix, [30, 125], 10, 1e-10, 0.01)
    cXY, objective, iter = ebc.run()
    clusters = cXY[0]       # only drug-gene pair cluster assignments
    for i in range(n):
        C = clusters[i]
        for j in range(i, n):
            if clusters[j] == C:
                Con_mat[i,j] += 1     # upper triangle of the matrix 
                if i != j: 
                    Con_mat[j,i] += 1   # lower triangle of the matrix without duplicating diagonal
    

np.savetxt("Co-occurrency_Mat.csv", Con_mat, delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f676f9dbb899> in <module>
#       1 import numpy as np
# ----> 2 from ebc import EBC
#       3 from matrix import SparseMatrix
#       4
#       5 with open("resources/matrix-ebc-paper-dense.tsv", "r") as f:
#
# ModuleNotFoundError: No module named 'ebc'

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("resources/matrix-ebc-paper-dense.tsv",sep='\t')
l=list(df.columns)

# rename column names
df.columns = ['drug-gene', 'row indicies', 'dependency path','column indicies','certainty']

df.loc[-1] = l  # adding a row
df.index = df.index + 1  # shifting index
df = df.sort_index()  # sorting by index              
df.head()

# %%
# dropping ALL duplicate values
df.drop_duplicates(subset ="drug-gene",
                     keep = "first", inplace = True)

df.head()
# Out:
#                    drug-gene row indicies              dependency path  \
# 0   (flavopiridol,nf-kappab)            0  [prep_by, activation, amod]
# 1            (tnf-r2,tnf-r1)            1     [appos, receptor, appos]
# 4                (il-2,il-5)            2          [appos, csf, appos]
# 22             (il-11,il-10)            3        [appos, pdgfa, appos]
# 25             (fgf-7,fgf-2)            4         [appos, vegf, appos]
#
#    column indicies certainty
# 0              781       1.0
# 1              413       1.0
# 4               24       1.0
# 22             335       1.0
# 25             127       1.0

# %%
#converting drug-gene pairs into a numpy array
arr = df["drug-gene"].to_numpy()

# %%
df1=pd.read_csv("Co-occurrency_Mat.csv")
li=list(df1.columns)

#converting the dataframe into numpy array
num=df1.to_numpy()
num = np.insert(num, 0, li, axis=0)


df2 = pd.DataFrame(data = num,
                   index = arr, 
                  columns = arr) 


                 
df2.astype(int)
# Out:
#                           (flavopiridol,nf-kappab)  (tnf-r2,tnf-r1)  \
# (flavopiridol,nf-kappab)                      1000              153
# (tnf-r2,tnf-r1)                                153             1000
# (il-2,il-5)                                    134              617
# (il-11,il-10)                                  100              522
# (fgf-7,fgf-2)                                   90              499
# ...                                            ...              ...
# (dexamethasone,nfkappab)                        33               18
# (propafenone,cyp1a2)                            32               22
# (cisplatin,brca1)                              118               75
# (ndga,nrf2)                                    322              191
# (zolmitriptan,5-ht1b)                          356              143
#
#                           (il-2,il-5)  (il-11,il-10)  (fgf-7,fgf-2)  \
# (flavopiridol,nf-kappab)          134            100             90
# (tnf-r2,tnf-r1)                   617            522            499
# (il-2,il-5)                      1000            628            572
# (il-11,il-10)                     628           1000            659
# (fgf-7,fgf-2)                     572            659           1000
# ...                               ...            ...            ...
# (dexamethasone,nfkappab)           19             12              8
# (propafenone,cyp1a2)               24             18             18
# (cisplatin,brca1)                  83             99            110
# (ndga,nrf2)                       243            204            151
# (zolmitriptan,5-ht1b)             110            105            125
#
#                           (clopidogrel,p-selectin)  (fgf-7,fgf-1)  \
# (flavopiridol,nf-kappab)                       154            105
# (tnf-r2,tnf-r1)                                117            425
# (il-2,il-5)                                    120            477
# (il-11,il-10)                                  119            574
# (fgf-7,fgf-2)                                  114            657
# ...                                            ...            ...
# (dexamethasone,nfkappab)                        54             10
# (propafenone,cyp1a2)                            57             17
# (cisplatin,brca1)                              174            183
# (ndga,nrf2)                                    200            159
# (zolmitriptan,5-ht1b)                          154            194
#
#                           (il-11,il-13)  (propranolol,beta2)  \
# (flavopiridol,nf-kappab)            110                  112
# (tnf-r2,tnf-r1)                     390                  172
# (il-2,il-5)                         446                  149
# (il-11,il-10)                       505                  113
# (fgf-7,fgf-2)                       532                   99
# ...                                 ...                  ...
# (dexamethasone,nfkappab)             10                  171
# (propafenone,cyp1a2)                 17                  146
# (cisplatin,brca1)                   164                   85
# (ndga,nrf2)                         161                   74
# (zolmitriptan,5-ht1b)               193                  148
#
#                           (isoflurane,caspase-3)  ...  (erythromycin,p-gp)  \
# (flavopiridol,nf-kappab)                     350  ...                  100
# (tnf-r2,tnf-r1)                              126  ...                   90
# (il-2,il-5)                                  134  ...                  101
# (il-11,il-10)                                118  ...                   96
# (fgf-7,fgf-2)                                114  ...                   88
# ...                                          ...  ...                  ...
# (dexamethasone,nfkappab)                      47  ...                   87
# (propafenone,cyp1a2)                          52  ...                  141
# (cisplatin,brca1)                            218  ...                  300
# (ndga,nrf2)                                  235  ...                  106
# (zolmitriptan,5-ht1b)                        268  ...                  234
#
#                           (methoxsalen,cyp2a6)  (atra,nf-kappab)  \
# (flavopiridol,nf-kappab)                    28               146
# (tnf-r2,tnf-r1)                             23                91
# (il-2,il-5)                                 22               110
# (il-11,il-10)                               14               135
# (fgf-7,fgf-2)                                7               158
# ...                                        ...               ...
# (dexamethasone,nfkappab)                   717                20
# (propafenone,cyp1a2)                       620                32
# (cisplatin,brca1)                          167               397
# (ndga,nrf2)                                 25               161
# (zolmitriptan,5-ht1b)                        9               441
#
#                           (delavirdine,cyp3a)  (pge2,ifn-gamma)  \
# (flavopiridol,nf-kappab)                   32               103
# (tnf-r2,tnf-r1)                            22               412
# (il-2,il-5)                                24               463
# (il-11,il-10)                              18               503
# (fgf-7,fgf-2)                              18               647
# ...                                       ...               ...
# (dexamethasone,nfkappab)                  660                12
# (propafenone,cyp1a2)                      999                19
# (cisplatin,brca1)                         184               116
# (ndga,nrf2)                                31               175
# (zolmitriptan,5-ht1b)                      31               125
#
#                           (dexamethasone,nfkappab)  (propafenone,cyp1a2)  \
# (flavopiridol,nf-kappab)                        33                    32
# (tnf-r2,tnf-r1)                                 18                    22
# (il-2,il-5)                                     19                    24
# (il-11,il-10)                                   12                    18
# (fgf-7,fgf-2)                                    8                    18
# ...                                            ...                   ...
# (dexamethasone,nfkappab)                      1000                   660
# (propafenone,cyp1a2)                           660                  1000
# (cisplatin,brca1)                              181                   185
# (ndga,nrf2)                                     18                    31
# (zolmitriptan,5-ht1b)                            9                    30
#
#                           (cisplatin,brca1)  (ndga,nrf2)  \
# (flavopiridol,nf-kappab)                118          322
# (tnf-r2,tnf-r1)                          75          191
# (il-2,il-5)                              83          243
# (il-11,il-10)                            99          204
# (fgf-7,fgf-2)                           110          151
# ...                                     ...          ...
# (dexamethasone,nfkappab)                181           18
# (propafenone,cyp1a2)                    185           31
# (cisplatin,brca1)                      1000          108
# (ndga,nrf2)                             108         1000
# (zolmitriptan,5-ht1b)                   282          175
#
#                           (zolmitriptan,5-ht1b)
# (flavopiridol,nf-kappab)                    356
# (tnf-r2,tnf-r1)                             143
# (il-2,il-5)                                 110
# (il-11,il-10)                               105
# (fgf-7,fgf-2)                               125
# ...                                         ...
# (dexamethasone,nfkappab)                      9
# (propafenone,cyp1a2)                         30
# (cisplatin,brca1)                           282
# (ndga,nrf2)                                 175
# (zolmitriptan,5-ht1b)                      1000
#
# [3514 rows x 3514 columns]

# %%
df2.to_csv("Co-occurrency_Matrix.csv")
