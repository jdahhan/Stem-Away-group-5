# %%
import numpy as np
from ebc import EBC 
from matrix import SparseMatrix

with open("resources/matrix-ebc-paper-sparse.tsv", "r") as f:
    data = []
    for line in f:
        sl = line.split("\t")
        if len(sl) < 5:  # headers
            continue
        data.append([sl[0], sl[2], float(sl[4])])


n = 14052      # unique drug-gene pairs
p = 7272      # unique dependency paths
matrix = SparseMatrix([n, p]) 
matrix.read_data(data)
matrix.normalize()


Con_mat = np.zeros((n, n), dtype=int) 
for k in range(100):
    ebc = EBC(matrix, [7, 25], 10, 1e-10, 0.01)
    cXY, objective, iter = ebc.run()
    clusters = cXY[0]
    for i in range(n):
        C = clusters[i]
        for j in range(i, n):
            if clusters[j] == C:
                Con_mat[i,j] += 1     # upper triangle of the matrix with diagonal
                if i != j: 
                    Con_mat[j,i] += 1   # lower triangle of the matrix without duplicating diagonal
# Out:
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.436251
# --> Running iteration 2 .. objective value = 6.411118
# --> Running iteration 3 .. objective value = 6.406774
# EBC finished in 3 iterations, with final objective value 6.4068
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.300809
# --> Running iteration 2 .. objective value = 6.189853
# --> Running iteration 3 .. objective value = 6.184770
# EBC finished in 3 iterations, with final objective value 6.1848
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.337652
# --> Running iteration 2 .. objective value = 6.308053
# --> Running iteration 3 .. objective value = 6.277431
# --> Running iteration 4 .. objective value = 6.276161
# EBC finished in 4 iterations, with final objective value 6.2762
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.531532
# --> Running iteration 2 .. objective value = 6.522136
# EBC finished in 2 iterations, with final objective value 6.5221
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.471628
# --> Running iteration 2 .. objective value = 6.462425
# EBC finished in 2 iterations, with final objective value 6.4624
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.351516
# --> Running iteration 2 .. objective value = 6.232360
# --> Running iteration 3 .. objective value = 6.199948
# --> Running iteration 4 .. objective value = 6.192789
# EBC finished in 4 iterations, with final objective value 6.1928
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.586103
# --> Running iteration 2 .. objective value = 6.579684
# EBC finished in 2 iterations, with final objective value 6.5797
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.639207
# --> Running iteration 2 .. objective value = 6.639121
# EBC finished in 2 iterations, with final objective value 6.6391
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.402929
# --> Running iteration 2 .. objective value = 6.382505
# --> Running iteration 3 .. objective value = 6.377226
# EBC finished in 3 iterations, with final objective value 6.3772
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.439413
# --> Running iteration 2 .. objective value = 6.365545
# --> Running iteration 3 .. objective value = 6.311728
# --> Running iteration 4 .. objective value = 6.299732
# --> Running iteration 5 .. objective value = 6.294222
# EBC finished in 5 iterations, with final objective value 6.2942
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.479278
# --> Running iteration 2 .. objective value = 6.367937
# --> Running iteration 3 .. objective value = 6.341070
# --> Running iteration 4 .. objective value = 6.321857
# --> Running iteration 5 .. objective value = 6.311148
# --> Running iteration 6 .. objective value = 6.306724
# EBC finished in 6 iterations, with final objective value 6.3067
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.551462
# --> Running iteration 2 .. objective value = 6.530115
# --> Running iteration 3 .. objective value = 6.525977
# EBC finished in 3 iterations, with final objective value 6.5260
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.469505
# --> Running iteration 2 .. objective value = 6.453555
# --> Running iteration 3 .. objective value = 6.449590
# EBC finished in 3 iterations, with final objective value 6.4496
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.363315
# --> Running iteration 2 .. objective value = 6.298500
# --> Running iteration 3 .. objective value = 6.249407
# --> Running iteration 4 .. objective value = 6.196297
# --> Running iteration 5 .. objective value = 6.167726
# --> Running iteration 6 .. objective value = 6.147577
# --> Running iteration 7 .. objective value = 6.144148
# EBC finished in 7 iterations, with final objective value 6.1441
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.556492
# --> Running iteration 2 .. objective value = 6.553465
# EBC finished in 2 iterations, with final objective value 6.5535
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.534795
# --> Running iteration 2 .. objective value = 6.505204
# --> Running iteration 3 .. objective value = 6.501554
# EBC finished in 3 iterations, with final objective value 6.5016
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.442247
# --> Running iteration 2 .. objective value = 6.422267
# --> Running iteration 3 .. objective value = 6.418612
# EBC finished in 3 iterations, with final objective value 6.4186
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.351038
# --> Running iteration 2 .. objective value = 6.320969
# --> Running iteration 3 .. objective value = 6.302579
# --> Running iteration 4 .. objective value = 6.297262
# EBC finished in 4 iterations, with final objective value 6.2973
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.474493
# --> Running iteration 2 .. objective value = 6.451152
# --> Running iteration 3 .. objective value = 6.450018
# EBC finished in 3 iterations, with final objective value 6.4500
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.524954
# --> Running iteration 2 .. objective value = 6.514970
# EBC finished in 2 iterations, with final objective value 6.5150
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.493421
# --> Running iteration 2 .. objective value = 6.482684
# --> Running iteration 3 .. objective value = 6.481358
# EBC finished in 3 iterations, with final objective value 6.4814
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.518543
# --> Running iteration 2 .. objective value = 6.503314
# --> Running iteration 3 .. objective value = 6.497850
# EBC finished in 3 iterations, with final objective value 6.4978
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.458808
# --> Running iteration 2 .. objective value = 6.445018
# --> Running iteration 3 .. objective value = 6.409439
# --> Running iteration 4 .. objective value = 6.380475
# --> Running iteration 5 .. objective value = 6.379137
# EBC finished in 5 iterations, with final objective value 6.3791
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.484635
# --> Running iteration 2 .. objective value = 6.480061
# EBC finished in 2 iterations, with final objective value 6.4801
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.378920
# --> Running iteration 2 .. objective value = 6.256790
# --> Running iteration 3 .. objective value = 6.253000
# EBC finished in 3 iterations, with final objective value 6.2530
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.412514
# --> Running iteration 2 .. objective value = 6.389798
# --> Running iteration 3 .. objective value = 6.386827
# EBC finished in 3 iterations, with final objective value 6.3868
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.447708
# --> Running iteration 2 .. objective value = 6.419146
# --> Running iteration 3 .. objective value = 6.408446
# --> Running iteration 4 .. objective value = 6.404961
# EBC finished in 4 iterations, with final objective value 6.4050
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.439176
# --> Running iteration 2 .. objective value = 6.381986
# --> Running iteration 3 .. objective value = 6.330545
# --> Running iteration 4 .. objective value = 6.296114
# --> Running iteration 5 .. objective value = 6.276903
# --> Running iteration 6 .. objective value = 6.256429
# --> Running iteration 7 .. objective value = 6.252578
# EBC finished in 7 iterations, with final objective value 6.2526
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.442065
# --> Running iteration 2 .. objective value = 6.223707
# --> Running iteration 3 .. objective value = 6.191351
# --> Running iteration 4 .. objective value = 6.187557
# EBC finished in 4 iterations, with final objective value 6.1876
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.415151
# --> Running iteration 2 .. objective value = 6.389654
# --> Running iteration 3 .. objective value = 6.384339
# EBC finished in 3 iterations, with final objective value 6.3843
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.584661
# --> Running iteration 2 .. objective value = 6.574437
# --> Running iteration 3 .. objective value = 6.572145
# EBC finished in 3 iterations, with final objective value 6.5721
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.378241
# --> Running iteration 2 .. objective value = 6.367484
# --> Running iteration 3 .. objective value = 6.363037
# EBC finished in 3 iterations, with final objective value 6.3630
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.322642
# --> Running iteration 2 .. objective value = 6.204586
# --> Running iteration 3 .. objective value = 6.176121
# --> Running iteration 4 .. objective value = 6.162840
# --> Running iteration 5 .. objective value = 6.159102
# EBC finished in 5 iterations, with final objective value 6.1591
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.567864
# --> Running iteration 2 .. objective value = 6.561142
# EBC finished in 2 iterations, with final objective value 6.5611
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.527424
# --> Running iteration 2 .. objective value = 6.516118
# --> Running iteration 3 .. objective value = 6.513246
# EBC finished in 3 iterations, with final objective value 6.5132
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.354005
# --> Running iteration 2 .. objective value = 6.326282
# --> Running iteration 3 .. objective value = 6.316138
# --> Running iteration 4 .. objective value = 6.313092
# EBC finished in 4 iterations, with final objective value 6.3131
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.518097
# --> Running iteration 2 .. objective value = 6.510683
# EBC finished in 2 iterations, with final objective value 6.5107
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.568493
# --> Running iteration 2 .. objective value = 6.558541
# EBC finished in 2 iterations, with final objective value 6.5585
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.440050
# --> Running iteration 2 .. objective value = 6.414742
# --> Running iteration 3 .. objective value = 6.410775
# EBC finished in 3 iterations, with final objective value 6.4108
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.544077
# --> Running iteration 2 .. objective value = 6.536031
# EBC finished in 2 iterations, with final objective value 6.5360
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.461567
# --> Running iteration 2 .. objective value = 6.425982
# --> Running iteration 3 .. objective value = 6.424839
# EBC finished in 3 iterations, with final objective value 6.4248
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.469251
# --> Running iteration 2 .. objective value = 6.457921
# --> Running iteration 3 .. objective value = 6.454149
# EBC finished in 3 iterations, with final objective value 6.4541
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.791176
# --> Running iteration 2 .. objective value = 6.790749
# EBC finished in 2 iterations, with final objective value 6.7907
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.434241
# --> Running iteration 2 .. objective value = 6.410512
# --> Running iteration 3 .. objective value = 6.407532
# EBC finished in 3 iterations, with final objective value 6.4075
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.349645
# --> Running iteration 2 .. objective value = 6.303641
# --> Running iteration 3 .. objective value = 6.296174
# EBC finished in 3 iterations, with final objective value 6.2962
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.325124
# --> Running iteration 2 .. objective value = 6.107104
# --> Running iteration 3 .. objective value = 6.081948
# --> Running iteration 4 .. objective value = 6.060400
# --> Running iteration 5 .. objective value = 6.050858
# EBC finished in 5 iterations, with final objective value 6.0509
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.418411
# --> Running iteration 2 .. objective value = 6.409203
# EBC finished in 2 iterations, with final objective value 6.4092
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.491154
# --> Running iteration 2 .. objective value = 6.479999
# --> Running iteration 3 .. objective value = 6.478297
# EBC finished in 3 iterations, with final objective value 6.4783
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.344585
# --> Running iteration 2 .. objective value = 6.246379
# --> Running iteration 3 .. objective value = 6.243314
# EBC finished in 3 iterations, with final objective value 6.2433
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.540870
# --> Running iteration 2 .. objective value = 6.528684
# --> Running iteration 3 .. objective value = 6.526902
# EBC finished in 3 iterations, with final objective value 6.5269
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.571312
# --> Running iteration 2 .. objective value = 6.571046
# EBC finished in 2 iterations, with final objective value 6.5710
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.499978
# --> Running iteration 2 .. objective value = 6.326705
# --> Running iteration 3 .. objective value = 6.066469
# --> Running iteration 4 .. objective value = 6.011063
# --> Running iteration 5 .. objective value = 6.006067
# EBC finished in 5 iterations, with final objective value 6.0061
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.431261
# --> Running iteration 2 .. objective value = 6.419238
# --> Running iteration 3 .. objective value = 6.412791
# EBC finished in 3 iterations, with final objective value 6.4128
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.498839
# --> Running iteration 2 .. objective value = 6.468036
# --> Running iteration 3 .. objective value = 6.463309
# EBC finished in 3 iterations, with final objective value 6.4633
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.388098
# --> Running iteration 2 .. objective value = 6.352015
# --> Running iteration 3 .. objective value = 6.348949
# EBC finished in 3 iterations, with final objective value 6.3489
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.386102
# --> Running iteration 2 .. objective value = 6.262767
# --> Running iteration 3 .. objective value = 6.204925
# --> Running iteration 4 .. objective value = 6.171043
# --> Running iteration 5 .. objective value = 6.141429
# --> Running iteration 6 .. objective value = 6.133500
# EBC finished in 6 iterations, with final objective value 6.1335
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.479914
# --> Running iteration 2 .. objective value = 6.473255
# EBC finished in 2 iterations, with final objective value 6.4733
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.272889
# --> Running iteration 2 .. objective value = 6.241909
# --> Running iteration 3 .. objective value = 6.234569
# EBC finished in 3 iterations, with final objective value 6.2346
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.440588
# --> Running iteration 2 .. objective value = 6.420829
# --> Running iteration 3 .. objective value = 6.416580
# EBC finished in 3 iterations, with final objective value 6.4166
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.337933
# --> Running iteration 2 .. objective value = 6.311581
# --> Running iteration 3 .. objective value = 6.305379
# EBC finished in 3 iterations, with final objective value 6.3054
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.305209
# --> Running iteration 2 .. objective value = 6.234317
# --> Running iteration 3 .. objective value = 6.212631
# --> Running iteration 4 .. objective value = 6.197814
# --> Running iteration 5 .. objective value = 6.185316
# --> Running iteration 6 .. objective value = 6.173286
# --> Running iteration 7 .. objective value = 6.171663
# EBC finished in 7 iterations, with final objective value 6.1717
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.592937
# --> Running iteration 2 .. objective value = 6.572126
# --> Running iteration 3 .. objective value = 6.571167
# EBC finished in 3 iterations, with final objective value 6.5712
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.393491
# --> Running iteration 2 .. objective value = 6.379235
# --> Running iteration 3 .. objective value = 6.360916
# --> Running iteration 4 .. objective value = 6.359514
# EBC finished in 4 iterations, with final objective value 6.3595
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.557567
# --> Running iteration 2 .. objective value = 6.552768
# EBC finished in 2 iterations, with final objective value 6.5528
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.472422
# --> Running iteration 2 .. objective value = 6.347413
# --> Running iteration 3 .. objective value = 6.161509
# --> Running iteration 4 .. objective value = 6.120262
# --> Running iteration 5 .. objective value = 6.114642
# EBC finished in 5 iterations, with final objective value 6.1146
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.518136
# --> Running iteration 2 .. objective value = 6.494377
# --> Running iteration 3 .. objective value = 6.487610
# EBC finished in 3 iterations, with final objective value 6.4876
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.499559
# --> Running iteration 2 .. objective value = 6.465314
# --> Running iteration 3 .. objective value = 6.463141
# EBC finished in 3 iterations, with final objective value 6.4631
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.364253
# --> Running iteration 2 .. objective value = 6.355374
# EBC finished in 2 iterations, with final objective value 6.3554
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.533653
# --> Running iteration 2 .. objective value = 6.504944
# --> Running iteration 3 .. objective value = 6.491715
# --> Running iteration 4 .. objective value = 6.491070
# EBC finished in 4 iterations, with final objective value 6.4911
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.532247
# --> Running iteration 2 .. objective value = 6.531478
# EBC finished in 2 iterations, with final objective value 6.5315
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.399601
# --> Running iteration 2 .. objective value = 6.299393
# --> Running iteration 3 .. objective value = 6.101148
# --> Running iteration 4 .. objective value = 6.074754
# --> Running iteration 5 .. objective value = 6.070844
# EBC finished in 5 iterations, with final objective value 6.0708
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.565327
# --> Running iteration 2 .. objective value = 6.551652
# --> Running iteration 3 .. objective value = 6.543833
# EBC finished in 3 iterations, with final objective value 6.5438
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.435848
# --> Running iteration 2 .. objective value = 6.421705
# --> Running iteration 3 .. objective value = 6.419254
# EBC finished in 3 iterations, with final objective value 6.4193
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.375474
# --> Running iteration 2 .. objective value = 6.361208
# --> Running iteration 3 .. objective value = 6.359852
# EBC finished in 3 iterations, with final objective value 6.3599
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.498145
# --> Running iteration 2 .. objective value = 6.479917
# --> Running iteration 3 .. objective value = 6.475904
# EBC finished in 3 iterations, with final objective value 6.4759
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.463281
# --> Running iteration 2 .. objective value = 6.456482
# EBC finished in 2 iterations, with final objective value 6.4565
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.478584
# --> Running iteration 2 .. objective value = 6.463484
# --> Running iteration 3 .. objective value = 6.459802
# EBC finished in 3 iterations, with final objective value 6.4598
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.386463
# --> Running iteration 2 .. objective value = 6.364953
# --> Running iteration 3 .. objective value = 6.360776
# EBC finished in 3 iterations, with final objective value 6.3608
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.552864
# --> Running iteration 2 .. objective value = 6.536293
# --> Running iteration 3 .. objective value = 6.534120
# EBC finished in 3 iterations, with final objective value 6.5341
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.427103
# --> Running iteration 2 .. objective value = 6.315950
# --> Running iteration 3 .. objective value = 6.104774
# --> Running iteration 4 .. objective value = 6.072574
# --> Running iteration 5 .. objective value = 6.070674
# EBC finished in 5 iterations, with final objective value 6.0707
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.390169
# --> Running iteration 2 .. objective value = 6.173112
# --> Running iteration 3 .. objective value = 6.164034
# EBC finished in 3 iterations, with final objective value 6.1640
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.476131
# --> Running iteration 2 .. objective value = 6.453347
# --> Running iteration 3 .. objective value = 6.452090
# EBC finished in 3 iterations, with final objective value 6.4521
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.421363
# --> Running iteration 2 .. objective value = 6.405104
# --> Running iteration 3 .. objective value = 6.401211
# EBC finished in 3 iterations, with final objective value 6.4012
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.445848
# --> Running iteration 2 .. objective value = 6.426483
# --> Running iteration 3 .. objective value = 6.423230
# EBC finished in 3 iterations, with final objective value 6.4232
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.506207
# --> Running iteration 2 .. objective value = 6.486286
# --> Running iteration 3 .. objective value = 6.485547
# EBC finished in 3 iterations, with final objective value 6.4855
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.474644
# --> Running iteration 2 .. objective value = 6.459554
# --> Running iteration 3 .. objective value = 6.453041
# EBC finished in 3 iterations, with final objective value 6.4530
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.439833
# --> Running iteration 2 .. objective value = 6.425799
# --> Running iteration 3 .. objective value = 6.420973
# EBC finished in 3 iterations, with final objective value 6.4210
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.513408
# --> Running iteration 2 .. objective value = 6.499336
# --> Running iteration 3 .. objective value = 6.498538
# EBC finished in 3 iterations, with final objective value 6.4985
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.458578
# --> Running iteration 2 .. objective value = 6.445115
# --> Running iteration 3 .. objective value = 6.435395
# EBC finished in 3 iterations, with final objective value 6.4354
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.537611
# --> Running iteration 2 .. objective value = 6.526664
# --> Running iteration 3 .. objective value = 6.525210
# EBC finished in 3 iterations, with final objective value 6.5252
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.424244
# --> Running iteration 2 .. objective value = 6.266917
# --> Running iteration 3 .. objective value = 6.070400
# --> Running iteration 4 .. objective value = 6.040271
# --> Running iteration 5 .. objective value = 6.036188
# EBC finished in 5 iterations, with final objective value 6.0362
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.334454
# --> Running iteration 2 .. objective value = 6.291749
# --> Running iteration 3 .. objective value = 6.271298
# --> Running iteration 4 .. objective value = 6.269565
# EBC finished in 4 iterations, with final objective value 6.2696
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.435060
# --> Running iteration 2 .. objective value = 6.415118
# --> Running iteration 3 .. objective value = 6.412192
# EBC finished in 3 iterations, with final objective value 6.4122
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.520993
# --> Running iteration 2 .. objective value = 6.503195
# --> Running iteration 3 .. objective value = 6.487721
# --> Running iteration 4 .. objective value = 6.487638
# EBC finished in 4 iterations, with final objective value 6.4876
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.453748
# --> Running iteration 2 .. objective value = 6.434161
# --> Running iteration 3 .. objective value = 6.432035
# EBC finished in 3 iterations, with final objective value 6.4320
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.466986
# --> Running iteration 2 .. objective value = 6.455779
# --> Running iteration 3 .. objective value = 6.450860
# EBC finished in 3 iterations, with final objective value 6.4509
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.483927
# --> Running iteration 2 .. objective value = 6.470025
# --> Running iteration 3 .. objective value = 6.469074
# EBC finished in 3 iterations, with final objective value 6.4691
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.328536
# --> Running iteration 2 .. objective value = 6.134688
# --> Running iteration 3 .. objective value = 6.114229
# --> Running iteration 4 .. objective value = 6.111979
# EBC finished in 4 iterations, with final objective value 6.1120
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.419289
# --> Running iteration 2 .. objective value = 6.406586
# --> Running iteration 3 .. objective value = 6.403323
# EBC finished in 3 iterations, with final objective value 6.4033
# Running EBC on a 2-d sparse matrix with size [14052, 7272] ...
# Randomly initializing clusters, with cluster number on each axis: [7, 25] ...
# --> Running iteration 1 .. objective value = 6.481298
# --> Running iteration 2 .. objective value = 6.473083
# EBC finished in 2 iterations, with final objective value 6.4731

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Pair_Path_Mapping/Pair_Path_Sparse.csv")

#converting drug-gene pairs into a numpy array
arr = df["drug-gene"].to_numpy()

# %%
#converting the 'Con_mat' numpy array into dataframe with rows & columns as same drug-gene pairs
df1 = pd.DataFrame(data = Con_mat,
                   index = arr, 
                  columns = arr)
df1.head()
# Out:
#                     (rc-160/igf-i)  (tnf-r2/tnf-r1)  (tiludronate/vegf)  \
# (rc-160/igf-i)                 100                9                  39
# (tnf-r2/tnf-r1)                  9              100                   8
# (tiludronate/vegf)              39                8                 100
# (il-11/il-10)                   12               44                   6
# (il-2/il-5)                      8               57                   7
#
#                     (il-11/il-10)  (il-2/il-5)  (actd/actc)  (il-11/il-16)  \
# (rc-160/igf-i)                 12            8           47             39
# (tnf-r2/tnf-r1)                44           57            8             10
# (tiludronate/vegf)              6            7           63             59
# (il-11/il-10)                 100           62            6              9
# (il-2/il-5)                    62          100            7              8
#
#                     (fgf-7/fgf-2)  (urokinase/fmlp)  (clopidogrel/p-selectin)  \
# (rc-160/igf-i)                 19                35                        37
# (tnf-r2/tnf-r1)                32                25                        16
# (tiludronate/vegf)             23                38                        42
# (il-11/il-10)                  50                13                        18
# (il-2/il-5)                    41                15                        18
#
#                     ...  (clodronate/vegf)  (cisplatin/mkp1)  \
# (rc-160/igf-i)      ...                 50                53
# (tnf-r2/tnf-r1)     ...                  4                 6
# (tiludronate/vegf)  ...                 62                57
# (il-11/il-10)       ...                  6                 7
# (il-2/il-5)         ...                  5                 5
#
#                     (paclitaxel/aromatase)  (dasatinib/parp)  \
# (rc-160/igf-i)                          46                52
# (tnf-r2/tnf-r1)                         11                 5
# (tiludronate/vegf)                      59                67
# (il-11/il-10)                            9                 8
# (il-2/il-5)                              7                 5
#
#                     (methoxsalen/cyp2a6)  (canertinib/erbb)  (saha/ctcl)  \
# (rc-160/igf-i)                         7                  9           37
# (tnf-r2/tnf-r1)                       19                 12            5
# (tiludronate/vegf)                     3                  7           47
# (il-11/il-10)                         16                  6            7
# (il-2/il-5)                           20                 10            5
#
#                     (tamoxifen/kallikrein)  (delavirdine/cyp3a)  \
# (rc-160/igf-i)                          49                   21
# (tnf-r2/tnf-r1)                          6                   18
# (tiludronate/vegf)                      56                   21
# (il-11/il-10)                            9                   10
# (il-2/il-5)                              6                   13
#
#                     (propafenone/cyp1a2)
# (rc-160/igf-i)                        19
# (tnf-r2/tnf-r1)                       15
# (tiludronate/vegf)                    18
# (il-11/il-10)                          8
# (il-2/il-5)                           10
#
# [5 rows x 14052 columns]

# %%
df1.to_csv("Co-occurrence_Sparse.csv")
